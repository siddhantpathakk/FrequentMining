# %%
import warnings

warnings.filterwarnings('ignore')

# %%
from constants import dataset_metadata, verbose
from task2_apriori import apriori_for_dataset

# %%
dataset_name = 'amazon-reviews'
dataset_metadata[dataset_name]
# Out:
# {'path': './data/amazon-reviews/all_csv_files.csv',
#  'size': 233055326,
#  'limit': 100000,
#  'minsup': [1500, 1000, 5000],
#  'threshold_rating': 4.0}

# %%
apriori_for_dataset(dataset_name, dataset_metadata, 
                    minsup_val=10000,
                    verbose=verbose)
# Out:
# Running Apriori on amazon-reviews : minsup = 10000
# ################################################################################
# Accessing chunk #1 with 100000 values.
# Num. of transactions: 63050
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 0
# Finished data-stream #1 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2 with 100000 values.
# Num. of transactions: 76287
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 0
# Finished data-stream #2 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #3 with 100000 values.
# Num. of transactions: 71687
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 0
# Finished data-stream #3 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #4 with 100000 values.
# Num. of transactions: 68496
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 0
# Finished data-stream #4 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #5 with 100000 values.
# Num. of transactions: 67939
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 0
# Finished data-stream #5 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #6 with 100000 values.
# Num. of transactions: 61726
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 0
# Finished data-stream #6 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #7 with 100000 values.
# Num. of transactions: 75105
# Num. of freq itemsets in this chunk: 2
# Total num. of freq itemsets till now: 2
# Finished data-stream #7 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #8 with 100000 values.
# Num. of transactions: 64506
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 3
# Finished data-stream #8 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #9 with 100000 values.
# Num. of transactions: 71544
# Num. of freq itemsets in this chunk: 3
# Total num. of freq itemsets till now: 6
# Finished data-stream #9 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #10 with 100000 values.
# Num. of transactions: 77104
# Num. of freq itemsets in this chunk: 2
# Total num. of freq itemsets till now: 8
# Finished data-stream #10 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #11 with 100000 values.
# Num. of transactions: 65257
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #11 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #12 with 100000 values.
# Num. of transactions: 68204
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #12 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #13 with 100000 values.
# Num. of transactions: 69505
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #13 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #14 with 100000 values.
# Num. of transactions: 70079
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #14 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #15 with 100000 values.
# Num. of transactions: 68326
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #15 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #16 with 100000 values.
# Num. of transactions: 64475
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #16 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #17 with 100000 values.
# Num. of transactions: 62635
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #17 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #18 with 100000 values.
# Num. of transactions: 62772
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #18 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #19 with 100000 values.
# Num. of transactions: 66412
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #19 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #20 with 100000 values.
# Num. of transactions: 59574
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #20 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #21 with 100000 values.
# Num. of transactions: 75155
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #21 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #22 with 100000 values.
# Num. of transactions: 76671
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #22 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #23 with 100000 values.
# Num. of transactions: 76858
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #23 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #24 with 100000 values.
# Num. of transactions: 75388
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #24 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #25 with 100000 values.
# Num. of transactions: 73213
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #25 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #26 with 100000 values.
# Num. of transactions: 72587
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #26 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #27 with 100000 values.
# Num. of transactions: 71408
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #27 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #28 with 100000 values.
# Num. of transactions: 67433
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #28 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #29 with 100000 values.
# Num. of transactions: 70541
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #29 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #30 with 100000 values.
# Num. of transactions: 67340
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #30 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #31 with 100000 values.
# Num. of transactions: 78774
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #31 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #32 with 100000 values.
# Num. of transactions: 81206
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #32 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #33 with 100000 values.
# Num. of transactions: 79842
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #33 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #34 with 100000 values.
# Num. of transactions: 76393
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #34 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #35 with 100000 values.
# Num. of transactions: 75385
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #35 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #36 with 100000 values.
# Num. of transactions: 73530
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #36 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #37 with 100000 values.
# Num. of transactions: 73543
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #37 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #38 with 100000 values.
# Num. of transactions: 73910
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #38 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #39 with 100000 values.
# Num. of transactions: 72539
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #39 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #40 with 100000 values.
# Num. of transactions: 72509
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #40 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #41 with 100000 values.
# Num. of transactions: 71882
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #41 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #42 with 100000 values.
# Num. of transactions: 74785
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #42 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #43 with 100000 values.
# Num. of transactions: 75380
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #43 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #44 with 100000 values.
# Num. of transactions: 72844
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #44 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #45 with 100000 values.
# Num. of transactions: 71858
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #45 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #46 with 100000 values.
# Num. of transactions: 73817
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #46 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #47 with 100000 values.
# Num. of transactions: 75145
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #47 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #48 with 100000 values.
# Num. of transactions: 74041
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #48 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #49 with 100000 values.
# Num. of transactions: 75243
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #49 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #50 with 100000 values.
# Num. of transactions: 76005
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #50 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #51 with 100000 values.
# Num. of transactions: 77508
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #51 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #52 with 100000 values.
# Num. of transactions: 75989
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #52 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #53 with 100000 values.
# Num. of transactions: 78727
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #53 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #54 with 100000 values.
# Num. of transactions: 75456
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #54 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #55 with 100000 values.
# Num. of transactions: 68960
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #55 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #56 with 100000 values.
# Num. of transactions: 69318
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #56 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #57 with 100000 values.
# Num. of transactions: 69141
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #57 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #58 with 100000 values.
# Num. of transactions: 69065
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #58 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #59 with 100000 values.
# Num. of transactions: 69664
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #59 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #60 with 100000 values.
# Num. of transactions: 70056
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #60 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #61 with 100000 values.
# Num. of transactions: 70658
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #61 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #62 with 100000 values.
# Num. of transactions: 70290
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #62 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #63 with 100000 values.
# Num. of transactions: 71076
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #63 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #64 with 100000 values.
# Num. of transactions: 74641
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #64 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #65 with 100000 values.
# Num. of transactions: 75668
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #65 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #66 with 100000 values.
# Num. of transactions: 76570
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #66 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #67 with 100000 values.
# Num. of transactions: 74035
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #67 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #68 with 100000 values.
# Num. of transactions: 74983
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #68 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #69 with 100000 values.
# Num. of transactions: 69457
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #69 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #70 with 100000 values.
# Num. of transactions: 75662
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #70 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #71 with 100000 values.
# Num. of transactions: 76633
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #71 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #72 with 100000 values.
# Num. of transactions: 75381
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #72 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #73 with 100000 values.
# Num. of transactions: 77181
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #73 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #74 with 100000 values.
# Num. of transactions: 77395
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #74 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #75 with 100000 values.
# Num. of transactions: 78979
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #75 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #76 with 100000 values.
# Num. of transactions: 78120
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #76 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #77 with 100000 values.
# Num. of transactions: 78486
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #77 in 1.7 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #78 with 100000 values.
# Num. of transactions: 78108
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #78 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #79 with 100000 values.
# Num. of transactions: 76402
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #79 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #80 with 100000 values.
# Num. of transactions: 77025
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #80 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #81 with 100000 values.
# Num. of transactions: 75446
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #81 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #82 with 100000 values.
# Num. of transactions: 77436
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #82 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #83 with 100000 values.
# Num. of transactions: 77790
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #83 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #84 with 100000 values.
# Num. of transactions: 76795
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #84 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #85 with 100000 values.
# Num. of transactions: 78784
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #85 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #86 with 100000 values.
# Num. of transactions: 77027
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #86 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #87 with 100000 values.
# Num. of transactions: 76832
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #87 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #88 with 100000 values.
# Num. of transactions: 78040
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #88 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #89 with 100000 values.
# Num. of transactions: 77646
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #89 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #90 with 100000 values.
# Num. of transactions: 78961
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #90 in 1.7 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #91 with 100000 values.
# Num. of transactions: 78239
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #91 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #92 with 100000 values.
# Num. of transactions: 78677
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #92 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #93 with 100000 values.
# Num. of transactions: 75622
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #93 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #94 with 100000 values.
# Num. of transactions: 78370
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #94 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #95 with 100000 values.
# Num. of transactions: 76354
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #95 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #96 with 100000 values.
# Num. of transactions: 77890
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #96 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #97 with 100000 values.
# Num. of transactions: 78325
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #97 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #98 with 100000 values.
# Num. of transactions: 78919
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #98 in 1.7 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #99 with 100000 values.
# Num. of transactions: 77786
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #99 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #100 with 100000 values.
# Num. of transactions: 76232
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #100 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #101 with 100000 values.
# Num. of transactions: 78198
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #101 in 1.7 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #102 with 100000 values.
# Num. of transactions: 77286
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #102 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #103 with 100000 values.
# Num. of transactions: 78266
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #103 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #104 with 100000 values.
# Num. of transactions: 78324
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #104 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #105 with 100000 values.
# Num. of transactions: 77005
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #105 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #106 with 100000 values.
# Num. of transactions: 77643
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #106 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #107 with 100000 values.
# Num. of transactions: 77425
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #107 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #108 with 100000 values.
# Num. of transactions: 78577
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #108 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #109 with 100000 values.
# Num. of transactions: 76900
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #109 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #110 with 100000 values.
# Num. of transactions: 76959
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #110 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #111 with 100000 values.
# Num. of transactions: 79192
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #111 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #112 with 100000 values.
# Num. of transactions: 75121
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #112 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #113 with 100000 values.
# Num. of transactions: 77015
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #113 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #114 with 100000 values.
# Num. of transactions: 70194
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #114 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #115 with 100000 values.
# Num. of transactions: 65525
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #115 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #116 with 100000 values.
# Num. of transactions: 71468
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #116 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #117 with 100000 values.
# Num. of transactions: 73719
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #117 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #118 with 100000 values.
# Num. of transactions: 71582
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #118 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #119 with 100000 values.
# Num. of transactions: 72328
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #119 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #120 with 100000 values.
# Num. of transactions: 73472
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #120 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #121 with 100000 values.
# Num. of transactions: 74797
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #121 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #122 with 100000 values.
# Num. of transactions: 74512
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #122 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #123 with 100000 values.
# Num. of transactions: 73126
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #123 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #124 with 100000 values.
# Num. of transactions: 74601
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #124 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #125 with 100000 values.
# Num. of transactions: 73594
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #125 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #126 with 100000 values.
# Num. of transactions: 76042
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #126 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #127 with 100000 values.
# Num. of transactions: 75516
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #127 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #128 with 100000 values.
# Num. of transactions: 74900
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #128 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #129 with 100000 values.
# Num. of transactions: 75031
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #129 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #130 with 100000 values.
# Num. of transactions: 73676
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #130 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #131 with 100000 values.
# Num. of transactions: 73523
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #131 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #132 with 100000 values.
# Num. of transactions: 74875
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #132 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #133 with 100000 values.
# Num. of transactions: 74721
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #133 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #134 with 100000 values.
# Num. of transactions: 73990
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #134 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #135 with 100000 values.
# Num. of transactions: 73985
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #135 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #136 with 100000 values.
# Num. of transactions: 73734
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #136 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #137 with 100000 values.
# Num. of transactions: 73116
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #137 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #138 with 100000 values.
# Num. of transactions: 72977
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #138 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #139 with 100000 values.
# Num. of transactions: 71618
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #139 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #140 with 100000 values.
# Num. of transactions: 72213
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #140 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #141 with 100000 values.
# Num. of transactions: 72068
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #141 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #142 with 100000 values.
# Num. of transactions: 72327
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #142 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #143 with 100000 values.
# Num. of transactions: 71286
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #143 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #144 with 100000 values.
# Num. of transactions: 71459
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #144 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #145 with 100000 values.
# Num. of transactions: 74085
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #145 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #146 with 100000 values.
# Num. of transactions: 71177
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 8
# Finished data-stream #146 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #147 with 100000 values.
# Num. of transactions: 76042
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 9
# Finished data-stream #147 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #148 with 100000 values.
# Num. of transactions: 75594
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 9
# Finished data-stream #148 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #149 with 100000 values.
# Num. of transactions: 73752
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 9
# Finished data-stream #149 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #150 with 100000 values.
# Num. of transactions: 79387
# Num. of freq itemsets in this chunk: 3
# Total num. of freq itemsets till now: 12
# Finished data-stream #150 in 1.7 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #151 with 100000 values.
# Num. of transactions: 70571
# Num. of freq itemsets in this chunk: 2
# Total num. of freq itemsets till now: 14
# Finished data-stream #151 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #152 with 100000 values.
# Num. of transactions: 80010
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 15
# Finished data-stream #152 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #153 with 100000 values.
# Num. of transactions: 77352
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #153 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #154 with 100000 values.
# Num. of transactions: 81059
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #154 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #155 with 100000 values.
# Num. of transactions: 75811
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #155 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #156 with 100000 values.
# Num. of transactions: 77614
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #156 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #157 with 100000 values.
# Num. of transactions: 72973
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #157 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #158 with 100000 values.
# Num. of transactions: 73477
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #158 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #159 with 100000 values.
# Num. of transactions: 72962
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #159 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #160 with 100000 values.
# Num. of transactions: 74002
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #160 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #161 with 100000 values.
# Num. of transactions: 73263
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #161 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #162 with 100000 values.
# Num. of transactions: 72402
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #162 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #163 with 100000 values.
# Num. of transactions: 72258
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #163 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #164 with 100000 values.
# Num. of transactions: 75140
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 15
# Finished data-stream #164 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #165 with 100000 values.
# Num. of transactions: 71126
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 16
# Finished data-stream #165 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #166 with 100000 values.
# Num. of transactions: 73310
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 17
# Finished data-stream #166 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #167 with 100000 values.
# Num. of transactions: 75025
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #167 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #168 with 100000 values.
# Num. of transactions: 72776
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #168 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #169 with 100000 values.
# Num. of transactions: 73256
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #169 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #170 with 100000 values.
# Num. of transactions: 71757
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #170 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #171 with 100000 values.
# Num. of transactions: 72481
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #171 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #172 with 100000 values.
# Num. of transactions: 76883
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #172 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #173 with 100000 values.
# Num. of transactions: 75036
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #173 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #174 with 100000 values.
# Num. of transactions: 75509
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 17
# Finished data-stream #174 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #175 with 100000 values.
# Num. of transactions: 76542
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 18
# Finished data-stream #175 in 1.6 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #176 with 100000 values.
# Num. of transactions: 69078
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 18
# Finished data-stream #176 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #177 with 100000 values.
# Num. of transactions: 71088
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 18
# Finished data-stream #177 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #178 with 100000 values.
# Num. of transactions: 75319
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 19
# Finished data-stream #178 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #179 with 100000 values.
# Num. of transactions: 72864
# Num. of freq itemsets in this chunk: 1
# Total num. of freq itemsets till now: 20
# Finished data-stream #179 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #180 with 100000 values.
# Num. of transactions: 73191
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 20
# Finished data-stream #180 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #181 with 100000 values.
# Num. of transactions: 72511
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 20
# Finished data-stream #181 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #182 with 100000 values.
# Num. of transactions: 71103
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 20
# Finished data-stream #182 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #183 with 100000 values.
# Num. of transactions: 73433
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 20
# Finished data-stream #183 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #184 with 100000 values.
# Num. of transactions: 79336
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 20
# Finished data-stream #184 in 1.7 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #185 with 100000 values.
# Num. of transactions: 78557
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 20
# Finished data-stream #185 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #186 with 100000 values.
# Num. of transactions: 82419
# Num. of freq itemsets in this chunk: 2
# Total num. of freq itemsets till now: 22
# Finished data-stream #186 in 1.7 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #187 with 100000 values.
# ...
# Accessing chunk #2272 with 100000 values.
# Num. of transactions: 75202
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2272 in 1.4 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2273 with 100000 values.
# Num. of transactions: 74745
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2273 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2274 with 100000 values.
# Num. of transactions: 76681
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2274 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2275 with 100000 values.
# Num. of transactions: 77241
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2275 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2276 with 100000 values.
# Num. of transactions: 72435
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2276 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2277 with 100000 values.
# Num. of transactions: 73317
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2277 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2278 with 100000 values.
# Num. of transactions: 73206
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2278 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2279 with 100000 values.
# Num. of transactions: 74786
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2279 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2280 with 100000 values.
# Num. of transactions: 75531
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2280 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2281 with 100000 values.
# Num. of transactions: 68038
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2281 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2282 with 100000 values.
# Num. of transactions: 69453
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2282 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2283 with 100000 values.
# Num. of transactions: 68913
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2283 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2284 with 100000 values.
# Num. of transactions: 69218
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2284 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2285 with 100000 values.
# Num. of transactions: 68826
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2285 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2286 with 100000 values.
# Num. of transactions: 70726
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2286 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2287 with 100000 values.
# Num. of transactions: 70135
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2287 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2288 with 100000 values.
# Num. of transactions: 68175
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2288 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2289 with 100000 values.
# Num. of transactions: 71826
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2289 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2290 with 100000 values.
# Num. of transactions: 70248
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2290 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2291 with 100000 values.
# Num. of transactions: 71824
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2291 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2292 with 100000 values.
# Num. of transactions: 70619
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2292 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2293 with 100000 values.
# Num. of transactions: 70585
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2293 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2294 with 100000 values.
# Num. of transactions: 70350
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2294 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2295 with 100000 values.
# Num. of transactions: 71436
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2295 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2296 with 100000 values.
# Num. of transactions: 70207
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2296 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2297 with 100000 values.
# Num. of transactions: 70526
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2297 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2298 with 100000 values.
# Num. of transactions: 70420
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2298 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2299 with 100000 values.
# Num. of transactions: 70481
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2299 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2300 with 100000 values.
# Num. of transactions: 69709
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2300 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2301 with 100000 values.
# Num. of transactions: 70003
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2301 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2302 with 100000 values.
# Num. of transactions: 69684
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2302 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2303 with 100000 values.
# Num. of transactions: 69661
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2303 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2304 with 100000 values.
# Num. of transactions: 69310
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2304 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2305 with 100000 values.
# Num. of transactions: 82389
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2305 in 1.5 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2306 with 100000 values.
# Num. of transactions: 57913
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2306 in 1.0 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2307 with 100000 values.
# Num. of transactions: 58992
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2307 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2308 with 100000 values.
# Num. of transactions: 63773
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2308 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2309 with 100000 values.
# Num. of transactions: 64231
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2309 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2310 with 100000 values.
# Num. of transactions: 63364
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2310 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2311 with 100000 values.
# Num. of transactions: 62880
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2311 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2312 with 100000 values.
# Num. of transactions: 66259
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2312 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2313 with 100000 values.
# Num. of transactions: 67428
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2313 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2314 with 100000 values.
# Num. of transactions: 68042
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2314 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2315 with 100000 values.
# Num. of transactions: 69662
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2315 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2316 with 100000 values.
# Num. of transactions: 66694
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2316 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2317 with 100000 values.
# Num. of transactions: 69882
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2317 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2318 with 100000 values.
# Num. of transactions: 69011
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2318 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2319 with 100000 values.
# Num. of transactions: 70275
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2319 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2320 with 100000 values.
# Num. of transactions: 71352
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2320 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2321 with 100000 values.
# Num. of transactions: 70389
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2321 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2322 with 100000 values.
# Num. of transactions: 71329
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2322 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2323 with 100000 values.
# Num. of transactions: 70233
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2323 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2324 with 100000 values.
# Num. of transactions: 66015
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2324 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2325 with 100000 values.
# Num. of transactions: 70411
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2325 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2326 with 100000 values.
# Num. of transactions: 69687
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2326 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2327 with 100000 values.
# Num. of transactions: 63417
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2327 in 1.2 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2328 with 100000 values.
# Num. of transactions: 54898
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2328 in 1.0 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2329 with 100000 values.
# Num. of transactions: 58304
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2329 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2330 with 100000 values.
# Num. of transactions: 59734
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2330 in 1.1 seconds.
# --------------------------------------------------------------------------------
# Accessing chunk #2331 with 55327 values.
# Num. of transactions: 35034
# Num. of freq itemsets: 0
# Total num. of freq itemsets till now: 113
# Finished data-stream #2331 in 0.6 seconds.
# --------------------------------------------------------------------------------
# Time taken for minsup 10000 = 0.7 seconds.
# Itemsets saved to ./logs/amazon-reviews/itemsets_df_minsup_10000.csv
# --------------------------------------------------------------------------------
#
# Completed amazon-reviews fp in 3380.3 seconds.
# ################################################################################
