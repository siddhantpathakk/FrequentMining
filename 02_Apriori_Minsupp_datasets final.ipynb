# %%
import pandas as pd
import time
import warnings
from apriori_algorithm import AprioriAlgorithm
from preprocessor import Streamer, preprocess

warnings.filterwarnings('ignore')

# %%
dataset_metadata = {
    'amazon-reviews': {
        'path': './data/amazon-reviews/all_csv_files.csv',
        'size': 233055326,
        'limit': 100000
    },
    
    'groceries': {
        'path': './data/groceries/Groceries_dataset.csv',
        'size': 38766,
        'limit': 10000
    },
    
    
    'movielens': {
        'path': ['./data/movielens/ratings.csv', './data/movielens/movies.csv'],
        'size': 100836, 
        'limit': 50000
    }
}

# %%
MIN_SUPPORT = 100
VERBOSE = False
DISPLAY_ITERATION = 5000

# %%
apriori = AprioriAlgorithm(minsup=MIN_SUPPORT, verbose=VERBOSE)

# %%
datasets = [
    'movielens',
    'groceries',
    'amazon-reviews',
    ]

# %%
threshold_rating = 4.0

# %%
for dataset in datasets:
    
    results = pd.DataFrame(columns=['item_sets', 'supp_count'])
    dataset_meta = dataset_metadata[dataset]
    num_streams = dataset_meta['size'] // dataset_meta['limit']
    
    if dataset == 'movielens':
        datastream = Streamer(filepath=dataset_meta['path'][0],
                              stream_limit=dataset_meta['limit'])
        movies_df = pd.read_csv(dataset_meta['path'][1])

    else:
        datastream = Streamer(filepath=dataset_meta['path'],
                            stream_limit=dataset_meta['limit'])
    
    print(f'Running APRIORI on {dataset} dataset with {num_streams} sequential I/O streams\n')
    print('--'*30)
    
    for stream_id in range(num_streams):

        start_time = time.time()
        
        df = datastream.getCurrentStream(stream_id)

        if dataset == 'movielens':
            movie_transactions = preprocess(dataset_name=dataset,
                                            ratings=df,
                                            movies=movies_df,
                                            threshold_rating=threshold_rating)

        else:
            movie_transactions = preprocess(dataset_name=dataset, 
                                            df=df, 
                                            threshold_rating=threshold_rating)
            
    
        freq_item_sets = apriori.run(movie_transactions)
        
        results = pd.concat([results, freq_item_sets], ignore_index=True)
        results = results.drop_duplicates()
        
            
        time_taken = round(time.time() - start_time, 2)

        print(f'Number of frequent itemsets found: {len(freq_item_sets)}')
        print(f'Number of transactions: {len(movie_transactions)}')
        print(f'Finished data-stream #{stream_id} in {time_taken} seconds.')
        # display(results) # uncomment to display results after each stream
                    
        print('--'*30)
    
    print(f'Finished running {dataset} dataset.')
    display(results)
    print("##"*30, '\n\n')
# Out:
# Running APRIORI on movielens dataset with 2 sequential I/O streams
#
# ------------------------------------------------------------
# Accessing data-stream #0
# Number of frequent itemsets found: 8
# Number of transactions: 322
# Finished data-stream #0 in 0.27 seconds.
# ------------------------------------------------------------
# Accessing data-stream #1
# Number of frequent itemsets found: 5
# Number of transactions: 288
# Finished data-stream #1 in 0.2 seconds.
# ------------------------------------------------------------
# Finished running movielens dataset.
#                               item_sets supp_count
# 0            ( The (1991),  The (1994))        105
# 1   ( The (1991), Silence of the Lambs)        114
# 2            ( The (1994),  The (1995))        106
# 3            ( The (1994),  The (1999))        119
# 4    ( The (1994), Forrest Gump (1994))        110
# 5    ( The (1994), Pulp Fiction (1994))        102
# 6   ( The (1994), Shawshank Redemption)        143
# 7                 ( The (1999), Matrix)        119
# 8   ( The (1991), Silence of the Lambs)        111
# 9            ( The (1994),  The (1999))        111
# 10   ( The (1994), Forrest Gump (1994))        101
# 11  ( The (1994), Shawshank Redemption)        131
# 12                ( The (1999), Matrix)        103
# ############################################################
#
#
# Running APRIORI on groceries dataset with 3 sequential I/O streams
#
# ------------------------------------------------------------
# Accessing data-stream #0
# Number of frequent itemsets found: 4
# Number of transactions: 3512
# Finished data-stream #0 in 0.23 seconds.
# ------------------------------------------------------------
# Accessing data-stream #1
# Number of frequent itemsets found: 1
# Number of transactions: 3664
# Finished data-stream #1 in 0.32 seconds.
# ------------------------------------------------------------
# Accessing data-stream #2
# Number of frequent itemsets found: 27
# Number of transactions: 3567
# Finished data-stream #2 in 0.34 seconds.
# ------------------------------------------------------------
# Finished running groceries dataset.
#                          item_sets supp_count
# 0           (frankfurter, sausage)        109
# 1        (frankfurter, whole milk)        102
# 2        (sausage, tropical fruit)        108
# 3            (sausage, whole milk)        146
# 4   (other vegetables, whole milk)        121
# 5                         UHT-milk        100
# 6                     bottled beer        159
# 7                    bottled water        261
# 8                      brown bread        194
# 9                           butter        191
# 10                     canned beer        148
# 11                          coffee        141
# 12                   cream cheese         132
# 13                            curd        169
# 14                         dessert        112
# 15                   domestic eggs        196
# 16               frozen vegetables        136
# 17           fruit/vegetable juice        158
# 18                       margarine        165
# 19                      newspapers        172
# 20                other vegetables        510
# 21                          pastry        239
# 22                       pip fruit        152
# 23                      rolls/buns        461
# 24                 root vegetables        245
# 25                   shopping bags        223
# 26                            soda        396
# 27                  tropical fruit        124
# 28              whipped/sour cream        216
# 29                     white bread        122
# 30                      whole milk        601
# 31                          yogurt        444
# ############################################################
#
#
# Running APRIORI on amazon-reviews dataset with 4661 sequential I/O streams
#
# ------------------------------------------------------------
# Accessing data-stream #0
# Number of frequent itemsets found: 0
# Number of transactions: 962
# Finished data-stream #0 in 0.06 seconds.
# ------------------------------------------------------------
# Accessing data-stream #1
# Number of frequent itemsets found: 0
# Number of transactions: 382
# Finished data-stream #1 in 0.05 seconds.
# ------------------------------------------------------------
# Accessing data-stream #2
# Number of frequent itemsets found: 0
# Number of transactions: 756
# Finished data-stream #2 in 0.07 seconds.
# ------------------------------------------------------------
# Accessing data-stream #3
# Number of frequent itemsets found: 0
# Number of transactions: 1055
# Finished data-stream #3 in 0.07 seconds.
# ------------------------------------------------------------
# Accessing data-stream #4
# Number of frequent itemsets found: 0
# Number of transactions: 1300
# Finished data-stream #4 in 0.08 seconds.
# ------------------------------------------------------------
# Accessing data-stream #5
# Number of frequent itemsets found: 0
# Number of transactions: 5290
# Finished data-stream #5 in 0.12 seconds.
# ------------------------------------------------------------
# Accessing data-stream #6
# Number of frequent itemsets found: 0
# Number of transactions: 12811
# Finished data-stream #6 in 0.21 seconds.
# ------------------------------------------------------------
# Accessing data-stream #7
# Number of frequent itemsets found: 0
# Number of transactions: 11079
# Finished data-stream #7 in 0.18 seconds.
# ------------------------------------------------------------
# Accessing data-stream #8
# Number of frequent itemsets found: 0
# Number of transactions: 650
# Finished data-stream #8 in 0.1 seconds.
# ------------------------------------------------------------
# Accessing data-stream #9
# Number of frequent itemsets found: 0
# Number of transactions: 1587
# Finished data-stream #9 in 0.14 seconds.
# ------------------------------------------------------------
# Accessing data-stream #10
# Number of frequent itemsets found: 0
# Number of transactions: 7462
# Finished data-stream #10 in 0.17 seconds.
# ------------------------------------------------------------
# Accessing data-stream #11
# Number of frequent itemsets found: 0
# Number of transactions: 10002
# Finished data-stream #11 in 0.19 seconds.
# ------------------------------------------------------------
# Accessing data-stream #12
# Number of frequent itemsets found: 0
# Number of transactions: 927
# Finished data-stream #12 in 0.13 seconds.
# ------------------------------------------------------------
# Accessing data-stream #13
# Number of frequent itemsets found: 0
# Number of transactions: 65
# Finished data-stream #13 in 0.13 seconds.
# ------------------------------------------------------------
# Accessing data-stream #14
# Number of frequent itemsets found: 0
# Number of transactions: 10
# Finished data-stream #14 in 0.13 seconds.
# ------------------------------------------------------------
# Accessing data-stream #15
# Number of frequent itemsets found: 0
# Number of transactions: 34
# Finished data-stream #15 in 0.14 seconds.
# ------------------------------------------------------------
# Accessing data-stream #16
# Number of frequent itemsets found: 0
# Number of transactions: 27
# Finished data-stream #16 in 0.15 seconds.
# ------------------------------------------------------------
# Accessing data-stream #17
# Number of frequent itemsets found: 0
# Number of transactions: 22
# Finished data-stream #17 in 0.15 seconds.
# ------------------------------------------------------------
# Accessing data-stream #18
# Number of frequent itemsets found: 0
# Number of transactions: 39
# Finished data-stream #18 in 0.16 seconds.
# ------------------------------------------------------------
# Accessing data-stream #19
# Number of frequent itemsets found: 0
# Number of transactions: 569
# Finished data-stream #19 in 0.18 seconds.
# ------------------------------------------------------------
# Accessing data-stream #20
# Number of frequent itemsets found: 0
# Number of transactions: 562
# Finished data-stream #20 in 0.19 seconds.
# ------------------------------------------------------------
# Accessing data-stream #21
# Number of frequent itemsets found: 0
# Number of transactions: 1220
# Finished data-stream #21 in 0.19 seconds.
# ------------------------------------------------------------
# Accessing data-stream #22
# Number of frequent itemsets found: 0
# Number of transactions: 1303
# Finished data-stream #22 in 0.2 seconds.
# ------------------------------------------------------------
# Accessing data-stream #23
# Number of frequent itemsets found: 0
# Number of transactions: 1826
# Finished data-stream #23 in 0.21 seconds.
# ------------------------------------------------------------
# Accessing data-stream #24
# Number of frequent itemsets found: 0
# Number of transactions: 1715
# Finished data-stream #24 in 0.21 seconds.
# ------------------------------------------------------------
# Accessing data-stream #25
# Number of frequent itemsets found: 0
# Number of transactions: 1768
# Finished data-stream #25 in 0.24 seconds.
# ------------------------------------------------------------
# Accessing data-stream #26
# Number of frequent itemsets found: 0
# Number of transactions: 2014
# Finished data-stream #26 in 0.23 seconds.
# ------------------------------------------------------------
# Accessing data-stream #27
# Number of frequent itemsets found: 0
# Number of transactions: 9260
# Finished data-stream #27 in 0.29 seconds.
# ------------------------------------------------------------
# Accessing data-stream #28
# Number of frequent itemsets found: 0
# Number of transactions: 14342
# Finished data-stream #28 in 0.36 seconds.
# ------------------------------------------------------------
# Accessing data-stream #29
# Number of frequent itemsets found: 0
# Number of transactions: 14982
# Finished data-stream #29 in 0.35 seconds.
# ------------------------------------------------------------
# Accessing data-stream #30
# Number of frequent itemsets found: 0
# Number of transactions: 14322
# Finished data-stream #30 in 0.37 seconds.
# ------------------------------------------------------------
# Accessing data-stream #31
# Number of frequent itemsets found: 0
# Number of transactions: 15090
# Finished data-stream #31 in 0.36 seconds.
# ------------------------------------------------------------
# Accessing data-stream #32
# Number of frequent itemsets found: 0
# Number of transactions: 14750
# Finished data-stream #32 in 0.38 seconds.
# ------------------------------------------------------------
# Accessing data-stream #33
# Number of frequent itemsets found: 0
# Number of transactions: 15118
# Finished data-stream #33 in 0.4 seconds.
# ------------------------------------------------------------
# Accessing data-stream #34
# Number of frequent itemsets found: 0
# Number of transactions: 15701
# Finished data-stream #34 in 0.4 seconds.
# ------------------------------------------------------------
# Accessing data-stream #35
# Number of frequent itemsets found: 0
# Number of transactions: 16071
# Finished data-stream #35 in 0.43 seconds.
# ------------------------------------------------------------
# Accessing data-stream #36
# Number of frequent itemsets found: 0
# Number of transactions: 15409
# Finished data-stream #36 in 0.43 seconds.
# ------------------------------------------------------------
# Accessing data-stream #37
# Number of frequent itemsets found: 0
# Number of transactions: 3810
# Finished data-stream #37 in 0.35 seconds.
# ------------------------------------------------------------
# Accessing data-stream #38
# Number of frequent itemsets found: 0
# Number of transactions: 656
# Finished data-stream #38 in 0.3 seconds.
# ------------------------------------------------------------
# Accessing data-stream #39
# Number of frequent itemsets found: 0
# Number of transactions: 655
# Finished data-stream #39 in 0.31 seconds.
# ------------------------------------------------------------
# Accessing data-stream #40
# Number of frequent itemsets found: 0
# Number of transactions: 743
# Finished data-stream #40 in 0.31 seconds.
# ------------------------------------------------------------
# Accessing data-stream #41
# Number of frequent itemsets found: 0
# Number of transactions: 691
# Finished data-stream #41 in 0.32 seconds.
# ------------------------------------------------------------
# Accessing data-stream #42
# Number of frequent itemsets found: 0
# Number of transactions: 859
# Finished data-stream #42 in 0.33 seconds.
# ------------------------------------------------------------
# Accessing data-stream #43
# Number of frequent itemsets found: 0
# Number of transactions: 1225
# Finished data-stream #43 in 0.33 seconds.
# ------------------------------------------------------------
# Accessing data-stream #44
# Number of frequent itemsets found: 0
# Number of transactions: 1330
# Finished data-stream #44 in 0.34 seconds.
# ------------------------------------------------------------
# Accessing data-stream #45
# Number of frequent itemsets found: 0
# Number of transactions: 1413
# Finished data-stream #45 in 0.34 seconds.
# ------------------------------------------------------------
# Accessing data-stream #46
# Number of frequent itemsets found: 0
# Number of transactions: 1423
# Finished data-stream #46 in 0.35 seconds.
# ------------------------------------------------------------
# Accessing data-stream #47
# Number of frequent itemsets found: 0
# Number of transactions: 1745
# Finished data-stream #47 in 0.35 seconds.
# ------------------------------------------------------------
# Accessing data-stream #48
# Number of frequent itemsets found: 0
# Number of transactions: 1729
# Finished data-stream #48 in 0.36 seconds.
# ------------------------------------------------------------
# Accessing data-stream #49
# Number of frequent itemsets found: 0
# Number of transactions: 5951
# Finished data-stream #49 in 0.4 seconds.
# ------------------------------------------------------------
# Accessing data-stream #50
# Number of frequent itemsets found: 0
# Number of transactions: 12164
# Finished data-stream #50 in 0.48 seconds.
# ------------------------------------------------------------
# Accessing data-stream #51
# Number of frequent itemsets found: 0
# Number of transactions: 13091
# Finished data-stream #51 in 0.5 seconds.
# ------------------------------------------------------------
# Accessing data-stream #52
# Number of frequent itemsets found: 0
# Number of transactions: 13369
# Finished data-stream #52 in 0.53 seconds.
# ------------------------------------------------------------
# Accessing data-stream #53
# Number of frequent itemsets found: 0
# Number of transactions: 12803
# Finished data-stream #53 in 0.48 seconds.
# ------------------------------------------------------------
# Accessing data-stream #54
# Number of frequent itemsets found: 0
# Number of transactions: 12906
# Finished data-stream #54 in 0.51 seconds.
# ------------------------------------------------------------
# Accessing data-stream #55
# Number of frequent itemsets found: 0
# Number of transactions: 12691
# Finished data-stream #55 in 0.5 seconds.
# ------------------------------------------------------------
# Accessing data-stream #56
# Number of frequent itemsets found: 0
# Number of transactions: 10987
# Finished data-stream #56 in 0.51 seconds.
# ------------------------------------------------------------
# Accessing data-stream #57
# Number of frequent itemsets found: 0
# Number of transactions: 291
# Finished data-stream #57 in 0.41 seconds.
# ------------------------------------------------------------
# Accessing data-stream #58
# Number of frequent itemsets found: 0
# Number of transactions: 376
# Finished data-stream #58 in 0.42 seconds.
# ------------------------------------------------------------
# Accessing data-stream #59
# Number of frequent itemsets found: 8
# Number of transactions: 565
# Finished data-stream #59 in 0.46 seconds.
# ------------------------------------------------------------
# Accessing data-stream #60
# Number of frequent itemsets found: 0
# Number of transactions: 580
# Finished data-stream #60 in 0.43 seconds.
# ------------------------------------------------------------
# Accessing data-stream #61
# Number of frequent itemsets found: 0
# Number of transactions: 913
# Finished data-stream #61 in 0.45 seconds.
# ------------------------------------------------------------
# Accessing data-stream #62
# Number of frequent itemsets found: 0
# Number of transactions: 773
# Finished data-stream #62 in 0.44 seconds.
# ------------------------------------------------------------
# Accessing data-stream #63
# Number of frequent itemsets found: 0
# Number of transactions: 1033
# Finished data-stream #63 in 0.48 seconds.
# ------------------------------------------------------------
# Accessing data-stream #64
# Number of frequent itemsets found: 0
# Number of transactions: 692
# Finished data-stream #64 in 0.47 seconds.
# ------------------------------------------------------------
# Accessing data-stream #65
# Number of frequent itemsets found: 0
# Number of transactions: 836
# Finished data-stream #65 in 0.53 seconds.
# ------------------------------------------------------------
# Accessing data-stream #66
# Number of frequent itemsets found: 0
# Number of transactions: 1964
# Finished data-stream #66 in 0.54 seconds.
# ------------------------------------------------------------
# Accessing data-stream #67
# Number of frequent itemsets found: 0
# Number of transactions: 9642
# Finished data-stream #67 in 0.64 seconds.
# ------------------------------------------------------------
# Accessing data-stream #68
# Number of frequent itemsets found: 0
# Number of transactions: 11596
# Finished data-stream #68 in 0.64 seconds.
# ------------------------------------------------------------
# Accessing data-stream #69
# Number of frequent itemsets found: 0
# Number of transactions: 4485
# Finished data-stream #69 in 0.57 seconds.
# ------------------------------------------------------------
# Accessing data-stream #70
# Number of frequent itemsets found: 0
# Number of transactions: 514
# Finished data-stream #70 in 0.54 seconds.
# ------------------------------------------------------------
# Accessing data-stream #71
# Number of frequent itemsets found: 0
# Number of transactions: 585
# Finished data-stream #71 in 0.55 seconds.
# ------------------------------------------------------------
# Accessing data-stream #72
# Number of frequent itemsets found: 0
# Number of transactions: 754
# Finished data-stream #72 in 0.56 seconds.
# ------------------------------------------------------------
# Accessing data-stream #73
# Number of frequent itemsets found: 0
# Number of transactions: 704
# Finished data-stream #73 in 0.6 seconds.
# ------------------------------------------------------------
# Accessing data-stream #74
# Number of frequent itemsets found: 0
# Number of transactions: 709
# Finished data-stream #74 in 0.59 seconds.
# ------------------------------------------------------------
# Accessing data-stream #75
# Number of frequent itemsets found: 0
# Number of transactions: 757
# Finished data-stream #75 in 0.6 seconds.
# ------------------------------------------------------------
# Accessing data-stream #76
# Number of frequent itemsets found: 0
# Number of transactions: 757
# Finished data-stream #76 in 0.59 seconds.
# ------------------------------------------------------------
# Accessing data-stream #77
# Number of frequent itemsets found: 0
# Number of transactions: 784
# Finished data-stream #77 in 0.59 seconds.
# ------------------------------------------------------------
# Accessing data-stream #78
# Number of frequent itemsets found: 0
# Number of transactions: 894
# Finished data-stream #78 in 0.61 seconds.
# ------------------------------------------------------------
# Accessing data-stream #79
# Number of frequent itemsets found: 0
# Number of transactions: 895
# Finished data-stream #79 in 0.61 seconds.
# ------------------------------------------------------------
# Accessing data-stream #80
# Number of frequent itemsets found: 0
# Number of transactions: 739
# Finished data-stream #80 in 0.61 seconds.
# ------------------------------------------------------------
# Accessing data-stream #81
# Number of frequent itemsets found: 0
# Number of transactions: 798
# Finished data-stream #81 in 0.65 seconds.
# ------------------------------------------------------------
# Accessing data-stream #82
# Number of frequent itemsets found: 0
# Number of transactions: 760
# Finished data-stream #82 in 0.67 seconds.
# ------------------------------------------------------------
# Accessing data-stream #83
# Number of frequent itemsets found: 0
# Number of transactions: 924
# Finished data-stream #83 in 0.64 seconds.
# ------------------------------------------------------------
# Accessing data-stream #84
# Number of frequent itemsets found: 0
# Number of transactions: 1102
# Finished data-stream #84 in 0.65 seconds.
# ------------------------------------------------------------
# Accessing data-stream #85
# Number of frequent itemsets found: 0
# Number of transactions: 954
# Finished data-stream #85 in 0.64 seconds.
# ------------------------------------------------------------
# Accessing data-stream #86
# Number of frequent itemsets found: 0
# Number of transactions: 1130
# Finished data-stream #86 in 0.65 seconds.
# ------------------------------------------------------------
# Accessing data-stream #87
# Number of frequent itemsets found: 0
# Number of transactions: 1191
# Finished data-stream #87 in 0.67 seconds.
# ------------------------------------------------------------
# Accessing data-stream #88
# Number of frequent itemsets found: 0
# Number of transactions: 1216
# Finished data-stream #88 in 0.66 seconds.
# ------------------------------------------------------------
# Accessing data-stream #89
# Number of frequent itemsets found: 0
# Number of transactions: 1086
# Finished data-stream #89 in 0.68 seconds.
# ------------------------------------------------------------
# Accessing data-stream #90
# Number of frequent itemsets found: 0
# Number of transactions: 1121
# Finished data-stream #90 in 0.69 seconds.
# ------------------------------------------------------------
# Accessing data-stream #91
# Number of frequent itemsets found: 0
# Number of transactions: 1118
# Finished data-stream #91 in 0.67 seconds.
# ------------------------------------------------------------
# Accessing data-stream #92
# Number of frequent itemsets found: 0
# Number of transactions: 1411
# Finished data-stream #92 in 0.69 seconds.
# ------------------------------------------------------------
# Accessing data-stream #93
# Number of frequent itemsets found: 0
# Number of transactions: 1170
# Finished data-stream #93 in 0.68 seconds.
# ------------------------------------------------------------
# Accessing data-stream #94
# Number of frequent itemsets found: 0
# Number of transactions: 1364
# Finished data-stream #94 in 0.69 seconds.
# ------------------------------------------------------------
# Accessing data-stream #95
# Number of frequent itemsets found: 0
# Number of transactions: 1655
# Finished data-stream #95 in 0.74 seconds.
# ------------------------------------------------------------
# Accessing data-stream #96
# Number of frequent itemsets found: 0
# Number of transactions: 1364
# Finished data-stream #96 in 0.71 seconds.
# ------------------------------------------------------------
# Accessing data-stream #97
# Number of frequent itemsets found: 0
# Number of transactions: 1309
# Finished data-stream #97 in 0.77 seconds.
# ------------------------------------------------------------
# Accessing data-stream #98
# Number of frequent itemsets found: 0
# Number of transactions: 1333
# Finished data-stream #98 in 0.75 seconds.
# ------------------------------------------------------------
# Accessing data-stream #99
# Number of frequent itemsets found: 0
# Number of transactions: 1375
# Finished data-stream #99 in 0.76 seconds.
# ------------------------------------------------------------
# Accessing data-stream #100
# Number of frequent itemsets found: 0
# Number of transactions: 1155
# Finished data-stream #100 in 0.75 seconds.
# ------------------------------------------------------------
# Accessing data-stream #101
# Number of frequent itemsets found: 0
# Number of transactions: 1291
# Finished data-stream #101 in 0.82 seconds.
# ------------------------------------------------------------
# Accessing data-stream #102
# Number of frequent itemsets found: 0
# Number of transactions: 1413
# Finished data-stream #102 in 0.84 seconds.
# ------------------------------------------------------------
# Accessing data-stream #103
# Number of frequent itemsets found: 0
# Number of transactions: 1207
# Finished data-stream #103 in 0.82 seconds.
# ------------------------------------------------------------
# Accessing data-stream #104
# Number of frequent itemsets found: 0
# Number of transactions: 1264
# Finished data-stream #104 in 0.86 seconds.
# ------------------------------------------------------------
# Accessing data-stream #105
# Number of frequent itemsets found: 0
# Number of transactions: 1083
# Finished data-stream #105 in 0.82 seconds.
# ------------------------------------------------------------
# Accessing data-stream #106
# Number of frequent itemsets found: 0
# Number of transactions: 1067
# Finished data-stream #106 in 0.84 seconds.
# ------------------------------------------------------------
# Accessing data-stream #107
# Number of frequent itemsets found: 0
# Number of transactions: 8754
# Finished data-stream #107 in 0.87 seconds.
# ------------------------------------------------------------
# Accessing data-stream #108
# Number of frequent itemsets found: 1
# Number of transactions: 9682
# Finished data-stream #108 in 0.9 seconds.
# ------------------------------------------------------------
# Accessing data-stream #109
# Number of frequent itemsets found: 0
# Number of transactions: 10960
# Finished data-stream #109 in 0.96 seconds.
# ------------------------------------------------------------
# Accessing data-stream #110
# Number of frequent itemsets found: 0
# Number of transactions: 11509
# Finished data-stream #110 in 0.95 seconds.
# ------------------------------------------------------------
# Accessing data-stream #111
# Number of frequent itemsets found: 0
# Number of transactions: 12742
# Finished data-stream #111 in 0.96 seconds.
# ------------------------------------------------------------
# Accessing data-stream #112
# Number of frequent itemsets found: 0
# Number of transactions: 13401
# Finished data-stream #112 in 1.09 seconds.
# ------------------------------------------------------------
# Accessing data-stream #113
# Number of frequent itemsets found: 0
# Number of transactions: 13708
# Finished data-stream #113 in 1.05 seconds.
# ------------------------------------------------------------
# Accessing data-stream #114
# Number of frequent itemsets found: 0
# Number of transactions: 13782
# Finished data-stream #114 in 0.98 seconds.
# ------------------------------------------------------------
# Accessing data-stream #115
# Number of frequent itemsets found: 0
# Number of transactions: 14018
# Finished data-stream #115 in 1.03 seconds.
# ------------------------------------------------------------
# Accessing data-stream #116
# Number of frequent itemsets found: 0
# Number of transactions: 15201
# Finished data-stream #116 in 1.02 seconds.
# ------------------------------------------------------------
# Accessing data-stream #117
# Number of frequent itemsets found: 0
# Number of transactions: 14900
# Finished data-stream #117 in 0.99 seconds.
# ------------------------------------------------------------
# Accessing data-stream #118
# Number of frequent itemsets found: 0
# Number of transactions: 15181
# Finished data-stream #118 in 1.02 seconds.
# ------------------------------------------------------------
# Accessing data-stream #119
# Number of frequent itemsets found: 0
# Number of transactions: 14820
# Finished data-stream #119 in 1.0 seconds.
# ------------------------------------------------------------
# Accessing data-stream #120
# Number of frequent itemsets found: 0
# Number of transactions: 15051
# Finished data-stream #120 in 1.05 seconds.
# ------------------------------------------------------------
# Accessing data-stream #121
# Number of frequent itemsets found: 0
# Number of transactions: 15196
# Finished data-stream #121 in 1.04 seconds.
# ------------------------------------------------------------
# Accessing data-stream #122
# Number of frequent itemsets found: 0
# Number of transactions: 14781
# Finished data-stream #122 in 1.01 seconds.
# ------------------------------------------------------------
# Accessing data-stream #123
# Number of frequent itemsets found: 0
# Number of transactions: 15247
# Finished data-stream #123 in 1.06 seconds.
# ------------------------------------------------------------
# Accessing data-stream #124
# Number of frequent itemsets found: 0
# Number of transactions: 14938
# Finished data-stream #124 in 1.04 seconds.
# ------------------------------------------------------------
# Accessing data-stream #125
# Number of frequent itemsets found: 0
# Number of transactions: 14822
# Finished data-stream #125 in 1.09 seconds.
# ------------------------------------------------------------
# Accessing data-stream #126
# Number of frequent itemsets found: 0
# Number of transactions: 13375
# Finished data-stream #126 in 1.07 seconds.
# ------------------------------------------------------------
# Accessing data-stream #127
# Number of frequent itemsets found: 0
# Number of transactions: 1567
# Finished data-stream #127 in 0.97 seconds.
# ------------------------------------------------------------
# Accessing data-stream #128
# Number of frequent itemsets found: 0
# Number of transactions: 715
# Finished data-stream #128 in 0.99 seconds.
# ------------------------------------------------------------
# Accessing data-stream #129
# Number of frequent itemsets found: 0
# Number of transactions: 707
# Finished data-stream #129 in 0.96 seconds.
# ------------------------------------------------------------
# Accessing data-stream #130
# Number of frequent itemsets found: 0
# Number of transactions: 733
# Finished data-stream #130 in 1.1 seconds.
# ------------------------------------------------------------
# Accessing data-stream #131
# Number of frequent itemsets found: 0
# Number of transactions: 691
# Finished data-stream #131 in 1.14 seconds.
# ------------------------------------------------------------
# Accessing data-stream #132
# Number of frequent itemsets found: 0
# Number of transactions: 440
# Finished data-stream #132 in 1.15 seconds.
# ------------------------------------------------------------
# Accessing data-stream #133
# Number of frequent itemsets found: 0
# Number of transactions: 597
# Finished data-stream #133 in 1.12 seconds.
# ------------------------------------------------------------
# Accessing data-stream #134
# Number of frequent itemsets found: 0
# Number of transactions: 700
# Finished data-stream #134 in 1.13 seconds.
# ------------------------------------------------------------
# Accessing data-stream #135
# Number of frequent itemsets found: 0
# Number of transactions: 848
# Finished data-stream #135 in 2.15 seconds.
# ------------------------------------------------------------
# Accessing data-stream #136
# Number of frequent itemsets found: 0
# Number of transactions: 1895
# Finished data-stream #136 in 1.97 seconds.
# ------------------------------------------------------------
# Accessing data-stream #137
# Number of frequent itemsets found: 0
# Number of transactions: 1417
# Finished data-stream #137 in 1.76 seconds.
# ------------------------------------------------------------
# Accessing data-stream #138
# Number of frequent itemsets found: 0
# Number of transactions: 1232
# Finished data-stream #138 in 1.42 seconds.
# ------------------------------------------------------------
# Accessing data-stream #139
# Number of frequent itemsets found: 0
# Number of transactions: 1188
# Finished data-stream #139 in 1.29 seconds.
# ------------------------------------------------------------
# Accessing data-stream #140
# Number of frequent itemsets found: 0
# Number of transactions: 997
# Finished data-stream #140 in 1.31 seconds.
# ------------------------------------------------------------
# Accessing data-stream #141
# Number of frequent itemsets found: 0
# Number of transactions: 842
# Finished data-stream #141 in 1.34 seconds.
# ------------------------------------------------------------
# Accessing data-stream #142
# Number of frequent itemsets found: 0
# Number of transactions: 1055
# Finished data-stream #142 in 1.27 seconds.
# ------------------------------------------------------------
# Accessing data-stream #143
# Number of frequent itemsets found: 0
# Number of transactions: 1069
# Finished data-stream #143 in 1.27 seconds.
# ------------------------------------------------------------
# Accessing data-stream #144
# Number of frequent itemsets found: 0
# Number of transactions: 999
# Finished data-stream #144 in 1.23 seconds.
# ------------------------------------------------------------
# Accessing data-stream #145
# Number of frequent itemsets found: 0
# Number of transactions: 965
# Finished data-stream #145 in 1.19 seconds.
# ------------------------------------------------------------
# Accessing data-stream #146
# Number of frequent itemsets found: 0
# Number of transactions: 1020
# Finished data-stream #146 in 1.21 seconds.
# ------------------------------------------------------------
# Accessing data-stream #147
# Number of frequent itemsets found: 0
# Number of transactions: 975
# Finished data-stream #147 in 1.19 seconds.
# ------------------------------------------------------------
# Accessing data-stream #148
# Number of frequent itemsets found: 0
# Number of transactions: 1099
# Finished data-stream #148 in 1.2 seconds.
# ------------------------------------------------------------
# Accessing data-stream #149
# Number of frequent itemsets found: 0
# Number of transactions: 1087
# Finished data-stream #149 in 1.36 seconds.
# ------------------------------------------------------------
# Accessing data-stream #150
# Number of frequent itemsets found: 0
# Number of transactions: 1070
# Finished data-stream #150 in 1.28 seconds.
# ------------------------------------------------------------
# Accessing data-stream #151
# Number of frequent itemsets found: 0
# Number of transactions: 1006
# Finished data-stream #151 in 1.22 seconds.
# ------------------------------------------------------------
# Accessing data-stream #152
# Number of frequent itemsets found: 0
# Number of transactions: 1102
# Finished data-stream #152 in 1.29 seconds.
# ------------------------------------------------------------
# Accessing data-stream #153
# Number of frequent itemsets found: 0
# Number of transactions: 1074
# Finished data-stream #153 in 1.27 seconds.
# ------------------------------------------------------------
# Accessing data-stream #154
# Number of frequent itemsets found: 0
# Number of transactions: 1239
# Finished data-stream #154 in 1.28 seconds.
# ------------------------------------------------------------
# Accessing data-stream #155
# Number of frequent itemsets found: 0
# Number of transactions: 1095
# Finished data-stream #155 in 1.53 seconds.
# ------------------------------------------------------------
# Accessing data-stream #156
# Number of frequent itemsets found: 0
# Number of transactions: 1161
# Finished data-stream #156 in 1.37 seconds.
# ------------------------------------------------------------
# Accessing data-stream #157
# Number of frequent itemsets found: 0
# Number of transactions: 1294
# Finished data-stream #157 in 1.41 seconds.
# ------------------------------------------------------------
# Accessing data-stream #158
# Number of frequent itemsets found: 0
# Number of transactions: 990
# Finished data-stream #158 in 1.29 seconds.
# ------------------------------------------------------------
# Accessing data-stream #159
# Number of frequent itemsets found: 0
# Number of transactions: 1051
# Finished data-stream #159 in 1.31 seconds.
# ------------------------------------------------------------
# Accessing data-stream #160
# Number of frequent itemsets found: 0
# Number of transactions: 997
# Finished data-stream #160 in 1.5 seconds.
# ------------------------------------------------------------
# Accessing data-stream #161
# Number of frequent itemsets found: 0
# Number of transactions: 1032
# Finished data-stream #161 in 1.43 seconds.
# ------------------------------------------------------------
# Accessing data-stream #162
# Number of frequent itemsets found: 0
# Number of transactions: 1218
# Finished data-stream #162 in 1.38 seconds.
# ------------------------------------------------------------
# Accessing data-stream #163
# Number of frequent itemsets found: 0
# Number of transactions: 1115
# Finished data-stream #163 in 1.37 seconds.
# ------------------------------------------------------------
# Accessing data-stream #164
# Number of frequent itemsets found: 0
# Number of transactions: 1055
# Finished data-stream #164 in 1.42 seconds.
# ------------------------------------------------------------
# Accessing data-stream #165
# Number of frequent itemsets found: 0
# Number of transactions: 900
# Finished data-stream #165 in 1.35 seconds.
# ------------------------------------------------------------
# Accessing data-stream #166
# Number of frequent itemsets found: 0
# Number of transactions: 962
# Finished data-stream #166 in 1.34 seconds.
# ------------------------------------------------------------
# Accessing data-stream #167
# Number of frequent itemsets found: 0
# Number of transactions: 992
# Finished data-stream #167 in 1.35 seconds.
# ------------------------------------------------------------
# Accessing data-stream #168
# Number of frequent itemsets found: 0
# Number of transactions: 1556
# Finished data-stream #168 in 1.4 seconds.
# ------------------------------------------------------------
# Accessing data-stream #169
# Number of frequent itemsets found: 0
# Number of transactions: 1231
# Finished data-stream #169 in 1.37 seconds.
# ------------------------------------------------------------
# Accessing data-stream #170
# Number of frequent itemsets found: 0
# Number of transactions: 1271
# Finished data-stream #170 in 1.38 seconds.
# ------------------------------------------------------------
# Accessing data-stream #171
# Number of frequent itemsets found: 0
# Number of transactions: 1216
# Finished data-stream #171 in 1.39 seconds.
# ------------------------------------------------------------
# Accessing data-stream #172
# Number of frequent itemsets found: 0
# Number of transactions: 1423
# Finished data-stream #172 in 1.44 seconds.
# ------------------------------------------------------------
# Accessing data-stream #173
# Number of frequent itemsets found: 0
# Number of transactions: 893
# Finished data-stream #173 in 1.42 seconds.
# ------------------------------------------------------------
# Accessing data-stream #174
# Number of frequent itemsets found: 0
# Number of transactions: 1457
# Finished data-stream #174 in 1.4 seconds.
# ------------------------------------------------------------
# Accessing data-stream #175
# Number of frequent itemsets found: 0
# Number of transactions: 1229
# Finished data-stream #175 in 1.43 seconds.
# ------------------------------------------------------------
# Accessing data-stream #176
# Number of frequent itemsets found: 0
# Number of transactions: 1287
# Finished data-stream #176 in 1.53 seconds.
# ------------------------------------------------------------
# Accessing data-stream #177
# Number of frequent itemsets found: 0
# Number of transactions: 1297
# Finished data-stream #177 in 1.47 seconds.
# ------------------------------------------------------------
# Accessing data-stream #178
# Number of frequent itemsets found: 0
# Number of transactions: 1333
# Finished data-stream #178 in 1.47 seconds.
# ------------------------------------------------------------
# Accessing data-stream #179
# Number of frequent itemsets found: 0
# Number of transactions: 1207
# Finished data-stream #179 in 1.5 seconds.
# ------------------------------------------------------------
# Accessing data-stream #180
# Number of frequent itemsets found: 0
# Number of transactions: 1316
# Finished data-stream #180 in 1.52 seconds.
# ------------------------------------------------------------
# Accessing data-stream #181
# Number of frequent itemsets found: 0
# Number of transactions: 1634
# Finished data-stream #181 in 1.44 seconds.
# ------------------------------------------------------------
# Accessing data-stream #182
# Number of frequent itemsets found: 0
# Number of transactions: 1320
# Finished data-stream #182 in 1.44 seconds.
# ------------------------------------------------------------
# Accessing data-stream #183
# Number of frequent itemsets found: 0
# Number of transactions: 1251
# Finished data-stream #183 in 1.47 seconds.
# ------------------------------------------------------------
# Accessing data-stream #184
# Number of frequent itemsets found: 0
# Number of transactions: 1111
# Finished data-stream #184 in 1.46 seconds.
# ------------------------------------------------------------
# Accessing data-stream #185
# Number of frequent itemsets found: 0
# Number of transactions: 1524
# Finished data-stream #185 in 1.51 seconds.
# ------------------------------------------------------------
# Accessing data-stream #186
# Number of frequent itemsets found: 0
# Number of transactions: 1371
# Finished data-stream #186 in 1.48 seconds.
# ------------------------------------------------------------
# Accessing data-stream #187
# Number of frequent itemsets found: 0
# Number of transactions: 1384
# Finished data-stream #187 in 1.52 seconds.
# ------------------------------------------------------------
# Accessing data-stream #188
# Number of frequent itemsets found: 0
# Number of transactions: 1018
# Finished data-stream #188 in 1.5 seconds.
# ------------------------------------------------------------
# Accessing data-stream #189
# Number of frequent itemsets found: 0
# Number of transactions: 1156
# Finished data-stream #189 in 1.51 seconds.
# ------------------------------------------------------------
# Accessing data-stream #190
# Number of frequent itemsets found: 0
# Number of transactions: 1275
# Finished data-stream #190 in 1.55 seconds.
# ------------------------------------------------------------
# Accessing data-stream #191
# Number of frequent itemsets found: 0
# Number of transactions: 1237
# Finished data-stream #191 in 1.78 seconds.
# ------------------------------------------------------------
# Accessing data-stream #192
# Number of frequent itemsets found: 0
# Number of transactions: 1222
# Finished data-stream #192 in 1.8 seconds.
# ------------------------------------------------------------
# Accessing data-stream #193
# Number of frequent itemsets found: 0
# Number of transactions: 1431
# Finished data-stream #193 in 1.68 seconds.
# ------------------------------------------------------------
# Accessing data-stream #194
# Number of frequent itemsets found: 0
# Number of transactions: 1166
# Finished data-stream #194 in 1.62 seconds.
# ------------------------------------------------------------
# Accessing data-stream #195
# Number of frequent itemsets found: 0
# Number of transactions: 1359
# Finished data-stream #195 in 1.55 seconds.
# ------------------------------------------------------------
# Accessing data-stream #196
# Number of frequent itemsets found: 0
# Number of transactions: 1578
# Finished data-stream #196 in 1.56 seconds.
# ------------------------------------------------------------
# Accessing data-stream #197
# Number of frequent itemsets found: 0
# Number of transactions: 1189
# Finished data-stream #197 in 1.58 seconds.
# ------------------------------------------------------------
# Accessing data-stream #198
# Number of frequent itemsets found: 0
# Number of transactions: 1405
# Finished data-stream #198 in 1.56 seconds.
# ------------------------------------------------------------
# Accessing data-stream #199
# Number of frequent itemsets found: 0
# Number of transactions: 739
# Finished data-stream #199 in 1.55 seconds.
# ------------------------------------------------------------
# Accessing data-stream #200
# Number of frequent itemsets found: 0
# Number of transactions: 1234
# Finished data-stream #200 in 1.61 seconds.
# ------------------------------------------------------------
# Accessing data-stream #201
# Number of frequent itemsets found: 0
# Number of transactions: 1187
# Finished data-stream #201 in 1.57 seconds.
# ------------------------------------------------------------
# Accessing data-stream #202
# Number of frequent itemsets found: 0
# Number of transactions: 1316
# Finished data-stream #202 in 1.72 seconds.
# ------------------------------------------------------------
# Accessing data-stream #203
# Number of frequent itemsets found: 0
# Number of transactions: 1417
# Finished data-stream #203 in 1.87 seconds.
# ------------------------------------------------------------
# Accessing data-stream #204
# Number of frequent itemsets found: 0
# Number of transactions: 1222
# Finished data-stream #204 in 1.71 seconds.
# ------------------------------------------------------------
# Accessing data-stream #205
# Number of frequent itemsets found: 0
# Number of transactions: 1143
# Finished data-stream #205 in 1.74 seconds.
# ------------------------------------------------------------
# Accessing data-stream #206
# Number of frequent itemsets found: 0
# Number of transactions: 1270
# Finished data-stream #206 in 1.77 seconds.
# ------------------------------------------------------------
# Accessing data-stream #207
# Number of frequent itemsets found: 0
# Number of transactions: 1130
# Finished data-stream #207 in 1.74 seconds.
# ------------------------------------------------------------
# Accessing data-stream #208
# Number of frequent itemsets found: 0
# Number of transactions: 1432
# Finished data-stream #208 in 1.73 seconds.
# ------------------------------------------------------------
# Accessing data-stream #209
# Number of frequent itemsets found: 0
# Number of transactions: 1377
# Finished data-stream #209 in 1.8 seconds.
# ------------------------------------------------------------
# Accessing data-stream #210
# Number of frequent itemsets found: 0
# Number of transactions: 1193
# Finished data-stream #210 in 1.74 seconds.
# ------------------------------------------------------------
# Accessing data-stream #211
# Number of frequent itemsets found: 0
# Number of transactions: 1089
# Finished data-stream #211 in 1.75 seconds.
# ------------------------------------------------------------
# Accessing data-stream #212
# Number of frequent itemsets found: 0
# Number of transactions: 1052
# Finished data-stream #212 in 1.76 seconds.
# ------------------------------------------------------------
# Accessing data-stream #213
# Number of frequent itemsets found: 0
# Number of transactions: 1275
# Finished data-stream #213 in 1.76 seconds.
# ------------------------------------------------------------
# Accessing data-stream #214
# Number of frequent itemsets found: 0
# Number of transactions: 1157
# Finished data-stream #214 in 1.75 seconds.
# ------------------------------------------------------------
# Accessing data-stream #215
# Number of frequent itemsets found: 0
# Number of transactions: 977
# Finished data-stream #215 in 1.83 seconds.
# ------------------------------------------------------------
# Accessing data-stream #216
# Number of frequent itemsets found: 0
# Number of transactions: 1401
# Finished data-stream #216 in 1.86 seconds.
# ------------------------------------------------------------
# Accessing data-stream #217
# Number of frequent itemsets found: 0
# Number of transactions: 1166
# Finished data-stream #217 in 1.82 seconds.
# ------------------------------------------------------------
# Accessing data-stream #218
# Number of frequent itemsets found: 0
# Number of transactions: 1205
# Finished data-stream #218 in 1.83 seconds.
# ------------------------------------------------------------
# Accessing data-stream #219
# Number of frequent itemsets found: 0
# Number of transactions: 1100
# Finished data-stream #219 in 1.8 seconds.
# ------------------------------------------------------------
# Accessing data-stream #220
# Number of frequent itemsets found: 0
# Number of transactions: 1161
# Finished data-stream #220 in 1.83 seconds.
# ------------------------------------------------------------
# Accessing data-stream #221
# Number of frequent itemsets found: 0
# Number of transactions: 1069
# Finished data-stream #221 in 1.88 seconds.
# ------------------------------------------------------------
# Accessing data-stream #222
# Number of frequent itemsets found: 0
# Number of transactions: 1106
# Finished data-stream #222 in 1.81 seconds.
# ------------------------------------------------------------
# Accessing data-stream #223
# Number of frequent itemsets found: 0
# Number of transactions: 1037
# Finished data-stream #223 in 1.83 seconds.
# ------------------------------------------------------------
# Accessing data-stream #224
# Number of frequent itemsets found: 0
# Number of transactions: 1262
# Finished data-stream #224 in 1.86 seconds.
# ------------------------------------------------------------
# Accessing data-stream #225
# Number of frequent itemsets found: 0
# Number of transactions: 2659
# Finished data-stream #225 in 1.9 seconds.
# ------------------------------------------------------------
# Accessing data-stream #226
# Number of frequent itemsets found: 0
# Number of transactions: 7511
# Finished data-stream #226 in 1.9 seconds.
# ------------------------------------------------------------
# Accessing data-stream #227
# Number of frequent itemsets found: 0
# Number of transactions: 9168
# Finished data-stream #227 in 1.96 seconds.
# ------------------------------------------------------------
# Accessing data-stream #228
# Number of frequent itemsets found: 0
# Number of transactions: 9986
# Finished data-stream #228 in 1.95 seconds.
# ------------------------------------------------------------
# Accessing data-stream #229
# Number of frequent itemsets found: 0
# Number of transactions: 9443
# Finished data-stream #229 in 1.94 seconds.
# ------------------------------------------------------------
# Accessing data-stream #230
# Number of frequent itemsets found: 0
# Number of transactions: 9308
# Finished data-stream #230 in 1.97 seconds.
# ------------------------------------------------------------
# Accessing data-stream #231
# Number of frequent itemsets found: 0
# Number of transactions: 9636
# Finished data-stream #231 in 2.0 seconds.
# ------------------------------------------------------------
# Accessing data-stream #232
# Number of frequent itemsets found: 0
# Number of transactions: 9691
# Finished data-stream #232 in 2.02 seconds.
# ------------------------------------------------------------
# Accessing data-stream #233
# Number of frequent itemsets found: 0
# Number of transactions: 10396
# Finished data-stream #233 in 2.03 seconds.
# ------------------------------------------------------------
# Accessing data-stream #234
# Number of frequent itemsets found: 0
# Number of transactions: 10958
# Finished data-stream #234 in 1.97 seconds.
# ------------------------------------------------------------
# Accessing data-stream #235
# Number of frequent itemsets found: 0
# Number of transactions: 10800
# Finished data-stream #235 in 2.02 seconds.
# ------------------------------------------------------------
# Accessing data-stream #236
# Number of frequent itemsets found: 0
# Number of transactions: 11448
# Finished data-stream #236 in 2.25 seconds.
# ------------------------------------------------------------
# Accessing data-stream #237
# Number of frequent itemsets found: 0
# Number of transactions: 14946
# Finished data-stream #237 in 2.15 seconds.
# ------------------------------------------------------------
# Accessing data-stream #238
# Number of frequent itemsets found: 0
# Number of transactions: 11921
# Finished data-stream #238 in 2.17 seconds.
# ------------------------------------------------------------
# Accessing data-stream #239
# Number of frequent itemsets found: 0
# Number of transactions: 10963
# Finished data-stream #239 in 2.22 seconds.
# ------------------------------------------------------------
# Accessing data-stream #240
# Number of frequent itemsets found: 0
# Number of transactions: 10593
# Finished data-stream #240 in 2.19 seconds.
# ------------------------------------------------------------
# Accessing data-stream #241
# Number of frequent itemsets found: 0
# Number of transactions: 12586
# Finished data-stream #241 in 2.12 seconds.
# ------------------------------------------------------------
# Accessing data-stream #242
# Number of frequent itemsets found: 0
# Number of transactions: 13297
# Finished data-stream #242 in 2.19 seconds.
# ------------------------------------------------------------
# Accessing data-stream #243
# Number of frequent itemsets found: 0
# Number of transactions: 11573
# Finished data-stream #243 in 2.14 seconds.
# ------------------------------------------------------------
# Accessing data-stream #244
# Number of frequent itemsets found: 0
# Number of transactions: 13633
# Finished data-stream #244 in 2.16 seconds.
# ------------------------------------------------------------
# Accessing data-stream #245
# Number of frequent itemsets found: 0
# Number of transactions: 15823
# Finished data-stream #245 in 2.27 seconds.
# ------------------------------------------------------------
# Accessing data-stream #246
# Number of frequent itemsets found: 0
# Number of transactions: 14077
# Finished data-stream #246 in 2.16 seconds.
# ------------------------------------------------------------
# Accessing data-stream #247
# Number of frequent itemsets found: 0
# Number of transactions: 13607
# Finished data-stream #247 in 2.22 seconds.
# ------------------------------------------------------------
# Accessing data-stream #248
# Number of frequent itemsets found: 0
# Number of transactions: 13060
# Finished data-stream #248 in 2.13 seconds.
# ------------------------------------------------------------
# Accessing data-stream #249
# Number of frequent itemsets found: 0
# Number of transactions: 13967
# Finished data-stream #249 in 2.18 seconds.
# ------------------------------------------------------------
# Accessing data-stream #250
# Number of frequent itemsets found: 0
# Number of transactions: 13592
# Finished data-stream #250 in 2.2 seconds.
# ------------------------------------------------------------
# Accessing data-stream #251
# Number of frequent itemsets found: 0
# Number of transactions: 13163
# Finished data-stream #251 in 2.76 seconds.
# ------------------------------------------------------------
# Accessing data-stream #252
# Number of frequent itemsets found: 0
# Number of transactions: 14875
# Finished data-stream #252 in 3.17 seconds.
# ------------------------------------------------------------
# Accessing data-stream #253
# Number of frequent itemsets found: 0
# Number of transactions: 13880
# Finished data-stream #253 in 2.67 seconds.
# ------------------------------------------------------------
# Accessing data-stream #254
# Number of frequent itemsets found: 0
# Number of transactions: 14716
# Finished data-stream #254 in 2.51 seconds.
# ------------------------------------------------------------
# Accessing data-stream #255
# Number of frequent itemsets found: 0
# Number of transactions: 13314
# Finished data-stream #255 in 2.24 seconds.
# ------------------------------------------------------------
# Accessing data-stream #256
# Number of frequent itemsets found: 0
# Number of transactions: 12528
# Finished data-stream #256 in 2.21 seconds.
# ------------------------------------------------------------
# Accessing data-stream #257
# Number of frequent itemsets found: 0
# Number of transactions: 13222
# Finished data-stream #257 in 2.66 seconds.
# ------------------------------------------------------------
# Accessing data-stream #258
# Number of frequent itemsets found: 0
# Number of transactions: 13767
# Finished data-stream #258 in 2.84 seconds.
# ------------------------------------------------------------
# Accessing data-stream #259
# Number of frequent itemsets found: 0
# Number of transactions: 16670
# Finished data-stream #259 in 2.92 seconds.
# ------------------------------------------------------------
# Accessing data-stream #260
# Number of frequent itemsets found: 0
# Number of transactions: 17048
# Finished data-stream #260 in 2.93 seconds.
# ------------------------------------------------------------
# Accessing data-stream #261
# Number of frequent itemsets found: 0
# Number of transactions: 17077
# Finished data-stream #261 in 2.88 seconds.
# ------------------------------------------------------------
# Accessing data-stream #262
# Number of frequent itemsets found: 0
# Number of transactions: 14933
# Finished data-stream #262 in 2.76 seconds.
# ------------------------------------------------------------
# Accessing data-stream #263
# Number of frequent itemsets found: 0
# Number of transactions: 16344
# Finished data-stream #263 in 2.69 seconds.
# ------------------------------------------------------------
# Accessing data-stream #264
# Number of frequent itemsets found: 0
# Number of transactions: 14532
# Finished data-stream #264 in 2.66 seconds.
# ------------------------------------------------------------
# Accessing data-stream #265
# Number of frequent itemsets found: 0
# Number of transactions: 14664
# Finished data-stream #265 in 2.66 seconds.
# ------------------------------------------------------------
# Accessing data-stream #266
# Number of frequent itemsets found: 0
# Number of transactions: 15990
# Finished data-stream #266 in 2.81 seconds.
# ------------------------------------------------------------
# Accessing data-stream #267
# Number of frequent itemsets found: 0
# Number of transactions: 15062
# Finished data-stream #267 in 2.75 seconds.
# ------------------------------------------------------------
# Accessing data-stream #268
# Number of frequent itemsets found: 0
# Number of transactions: 13024
# Finished data-stream #268 in 2.89 seconds.
# ------------------------------------------------------------
# Accessing data-stream #269
# Number of frequent itemsets found: 0
# Number of transactions: 14396
# Finished data-stream #269 in 2.77 seconds.
# ------------------------------------------------------------
# Accessing data-stream #270
# Number of frequent itemsets found: 0
# Number of transactions: 14748
# Finished data-stream #270 in 2.69 seconds.
# ------------------------------------------------------------
# Accessing data-stream #271
# Number of frequent itemsets found: 0
# Number of transactions: 14512
# Finished data-stream #271 in 2.7 seconds.
# ------------------------------------------------------------
# Accessing data-stream #272
# Number of frequent itemsets found: 0
# Number of transactions: 14766
# Finished data-stream #272 in 2.77 seconds.
# ------------------------------------------------------------
# Accessing data-stream #273
# Number of frequent itemsets found: 0
# Number of transactions: 14352
# Finished data-stream #273 in 3.17 seconds.
# ------------------------------------------------------------
# Accessing data-stream #274
# Number of frequent itemsets found: 0
# Number of transactions: 15010
# Finished data-stream #274 in 2.94 seconds.
# ------------------------------------------------------------
# Accessing data-stream #275
# Number of frequent itemsets found: 0
# Number of transactions: 13206
# Finished data-stream #275 in 2.77 seconds.
# ------------------------------------------------------------
# Accessing data-stream #276
# Number of frequent itemsets found: 0
# Number of transactions: 13920
# Finished data-stream #276 in 2.77 seconds.
# ------------------------------------------------------------
# Accessing data-stream #277
# Number of frequent itemsets found: 0
# Number of transactions: 14567
# Finished data-stream #277 in 2.79 seconds.
# ------------------------------------------------------------
# Accessing data-stream #278
# Number of frequent itemsets found: 0
# Number of transactions: 14081
# Finished data-stream #278 in 3.16 seconds.
# ------------------------------------------------------------
# Accessing data-stream #279
# Number of frequent itemsets found: 0
# Number of transactions: 14273
# Finished data-stream #279 in 3.21 seconds.
# ------------------------------------------------------------
# Accessing data-stream #280
# Number of frequent itemsets found: 0
# Number of transactions: 14244
# Finished data-stream #280 in 3.03 seconds.
# ------------------------------------------------------------
# Accessing data-stream #281
# Number of frequent itemsets found: 0
# Number of transactions: 15103
# Finished data-stream #281 in 3.48 seconds.
# ------------------------------------------------------------
# Accessing data-stream #282
# Number of frequent itemsets found: 0
# Number of transactions: 13901
# Finished data-stream #282 in 3.02 seconds.
# ------------------------------------------------------------
# Accessing data-stream #283
# Number of frequent itemsets found: 0
# Number of transactions: 16108
# Finished data-stream #283 in 2.95 seconds.
# ------------------------------------------------------------
# Accessing data-stream #284
# Number of frequent itemsets found: 0
# Number of transactions: 13128
# Finished data-stream #284 in 3.1 seconds.
# ------------------------------------------------------------
# Accessing data-stream #285
# Number of frequent itemsets found: 0
# Number of transactions: 13155
# Finished data-stream #285 in 2.99 seconds.
# ------------------------------------------------------------
# Accessing data-stream #286
# Number of frequent itemsets found: 0
# Number of transactions: 12100
# Finished data-stream #286 in 2.93 seconds.
# ------------------------------------------------------------
# Accessing data-stream #287
# Number of frequent itemsets found: 0
# Number of transactions: 502
# Finished data-stream #287 in 2.82 seconds.
# ------------------------------------------------------------
# Accessing data-stream #288
# Number of frequent itemsets found: 0
# Number of transactions: 1028
# Finished data-stream #288 in 2.94 seconds.
# ------------------------------------------------------------
# Accessing data-stream #289
# Number of frequent itemsets found: 0
# Number of transactions: 9201
# Finished data-stream #289 in 2.94 seconds.
# ------------------------------------------------------------
# Accessing data-stream #290
# Number of frequent itemsets found: 0
# Number of transactions: 2702
# Finished data-stream #290 in 2.97 seconds.
# ------------------------------------------------------------
# Accessing data-stream #291
# Number of frequent itemsets found: 0
# Number of transactions: 205
# Finished data-stream #291 in 2.91 seconds.
# ------------------------------------------------------------
# Accessing data-stream #292
# Number of frequent itemsets found: 0
# Number of transactions: 308
# Finished data-stream #292 in 2.81 seconds.
# ------------------------------------------------------------
# Accessing data-stream #293
# Number of frequent itemsets found: 0
# Number of transactions: 257
# Finished data-stream #293 in 2.91 seconds.
# ------------------------------------------------------------
# Accessing data-stream #294
# Number of frequent itemsets found: 0
# Number of transactions: 169
# Finished data-stream #294 in 2.85 seconds.
# ------------------------------------------------------------
# Accessing data-stream #295
# Number of frequent itemsets found: 0
# Number of transactions: 191
# Finished data-stream #295 in 2.88 seconds.
# ------------------------------------------------------------
# Accessing data-stream #296
# Number of frequent itemsets found: 0
# Number of transactions: 231
# Finished data-stream #296 in 2.92 seconds.
# ------------------------------------------------------------
# Accessing data-stream #297
# Number of frequent itemsets found: 0
# Number of transactions: 224
# Finished data-stream #297 in 2.95 seconds.
# ------------------------------------------------------------
# Accessing data-stream #298
# Number of frequent itemsets found: 0
# Number of transactions: 78
# Finished data-stream #298 in 3.33 seconds.
# ------------------------------------------------------------
# Accessing data-stream #299
# Number of frequent itemsets found: 0
# Number of transactions: 101
# Finished data-stream #299 in 3.1 seconds.
# ------------------------------------------------------------
# Accessing data-stream #300
# Number of frequent itemsets found: 0
# Number of transactions: 97
# Finished data-stream #300 in 3.02 seconds.
# ------------------------------------------------------------
# Accessing data-stream #301
# Number of frequent itemsets found: 0
# Number of transactions: 141
# Finished data-stream #301 in 2.87 seconds.
# ------------------------------------------------------------
# Accessing data-stream #302
# Number of frequent itemsets found: 0
# Number of transactions: 105
# Finished data-stream #302 in 2.88 seconds.
# ------------------------------------------------------------
# Accessing data-stream #303
# Number of frequent itemsets found: 0
# Number of transactions: 172
# Finished data-stream #303 in 2.82 seconds.
# ------------------------------------------------------------
# Accessing data-stream #304
# Number of frequent itemsets found: 0
# Number of transactions: 234
# Finished data-stream #304 in 3.16 seconds.
# ------------------------------------------------------------
# Accessing data-stream #305
# Number of frequent itemsets found: 0
# Number of transactions: 395
# Finished data-stream #305 in 2.98 seconds.
# ------------------------------------------------------------
# Accessing data-stream #306
