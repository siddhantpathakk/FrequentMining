# %%
import pandas as pd
import time
import warnings
from apriori_algorithm import AprioriAlgorithm
from preprocessor import Streamer, preprocess
from colorama import Fore

warnings.filterwarnings('ignore')

# %%
dataset_metadata = {
    'amazon-reviews': {
        'path': './data/amazon-reviews/all_csv_files.csv',

        # using only half the dataset
        'size': 233055326//2,  # original size = 233055326

        'limit': 70000,
        'minsup': [1000]
    },

    'groceries': {
        'path': './data/groceries/Groceries_dataset.csv',
        'size': 38766,
        'limit': 10000,
        'minsup': [200, 150, 100, 50, 25, 10]
    },


    'movielens': {
        'path': ['./data/movielens/ratings.csv', './data/movielens/movies.csv'],
        'size': 100836,
        'limit': 50000,
        'minsup': [500, 400, 300, 200, 100, 50]
    }
}

# %%
MIN_SUPPORT = 100
VERBOSE = False
DISPLAY_ITERATION = 5000

# %%
datasets = [
    # 'groceries',
    # 'movielens',
    'amazon-reviews',
    ]

# %%
threshold_rating = 4.0

# %%
for dataset in datasets:
    
    results = pd.DataFrame(columns=['item_sets', 'supp_count'])
    dataset_meta = dataset_metadata[dataset]
    num_streams = dataset_meta['size'] // dataset_meta['limit']
    
    total_time = 0
    total_timer = time.time()
    
    total_itemsets = 0
    
    for minsup in dataset_meta['minsup']:
        
        apriori = AprioriAlgorithm(minsup= minsup, verbose=VERBOSE)
        
        if dataset == 'movielens':
            datastream = Streamer(filepath=dataset_meta['path'][0],
                                stream_limit=dataset_meta['limit'])
            movies_df = pd.read_csv(dataset_meta['path'][1])

        else:
            datastream = Streamer(filepath=dataset_meta['path'],
                                stream_limit=dataset_meta['limit'])
        
        print(Fore.WHITE + f'Running Apriori on {dataset} : streams = {num_streams} , minsup = {minsup}')
        print(Fore.WHITE + "##"*40)
        
        for stream_id in range(num_streams):

            start_time = time.time()
            df = datastream.getCurrentStream(stream_id)

            if dataset == 'movielens':
                movie_transactions = preprocess(dataset_name=dataset,
                                                ratings=df,
                                                movies=movies_df,
                                                threshold_rating=threshold_rating)

            else:
                movie_transactions = preprocess(dataset_name=dataset, 
                                                df=df, 
                                                threshold_rating=threshold_rating)
                
        
            freq_item_sets = apriori.run(movie_transactions)
            
            results = pd.concat([results, freq_item_sets], ignore_index=True)
            results = results.drop_duplicates()
            
            total_itemsets += len(freq_item_sets)
            
            print(Fore.WHITE + f'\tAccessing data-stream #{stream_id}')
            print(Fore.GREEN + f'\tNum. of transactions: {len(movie_transactions)}')
            if len(freq_item_sets)>0:
                print(Fore.WHITE + f'\tNum. of freq itemsets:',
                      Fore.GREEN + f'{len(freq_item_sets)}')
            else:
                print(Fore.WHITE + f'\tNum. of freq itemsets: {len(freq_item_sets)}')
            
            print(Fore.WHITE + f'\tTotal num. of freq itemsets:',
                    Fore.GREEN + f'{total_itemsets}')
            
            time_taken = round(time.time() - start_time, 2)
            print(Fore.WHITE + f'\tFinished data-stream #{stream_id} in {time_taken} seconds.')

            print(Fore.WHITE + '--'*40)

        # display(results)
        results.to_csv(f'./logs/{dataset}/itemsets_df_minsup_{minsup}.csv', index=False)
        
    
    total_time += time.time() - total_timer
    print(Fore.GREEN +
          f'Completed {dataset} dataset in {total_time:.2f} seconds.')


    print(Fore.WHITE + "##"*40, '\n\n')
# Out:
# Running Apriori on amazon-reviews : streams = 1664 , minsup = 1000
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 48514
# 	Num. of freq itemsets: 5
# 	Finished data-stream #0 in 0.68 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 46863
# 	Num. of freq itemsets: 6
# 	Finished data-stream #1 in 0.69 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #2
# 	Num. of transactions: 52371
# 	Num. of freq itemsets: 3
# 	Finished data-stream #2 in 0.59 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #3
# 	Num. of transactions: 49945
# 	Num. of freq itemsets: 3
# 	Finished data-stream #3 in 0.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #4
# 	Num. of transactions: 50121
# 	Num. of freq itemsets: 0
# 	Finished data-stream #4 in 0.58 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #5
# 	Num. of transactions: 44602
# 	Num. of freq itemsets: 1
# 	Finished data-stream #5 in 0.55 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #6
# 	Num. of transactions: 50171
# 	Num. of freq itemsets: 3
# 	Finished data-stream #6 in 0.6 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #7
# 	Num. of transactions: 45911
# 	Num. of freq itemsets: 1
# 	Finished data-stream #7 in 0.58 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #8
# 	Num. of transactions: 46400
# 	Num. of freq itemsets: 3
# 	Finished data-stream #8 in 0.58 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #9
# 	Num. of transactions: 52353
# 	Num. of freq itemsets: 10
# 	Finished data-stream #9 in 1.13 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #10
# 	Num. of transactions: 43044
# 	Num. of freq itemsets: 1
# 	Finished data-stream #10 in 0.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #11
# 	Num. of transactions: 52607
# 	Num. of freq itemsets: 10
# 	Finished data-stream #11 in 1.13 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #12
# 	Num. of transactions: 50342
# 	Num. of freq itemsets: 1
# 	Finished data-stream #12 in 1.14 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #13
# 	Num. of transactions: 54023
# 	Num. of freq itemsets: 9
# 	Finished data-stream #13 in 1.13 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #14
# 	Num. of transactions: 39958
# 	Num. of freq itemsets: 3
# 	Finished data-stream #14 in 1.25 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #15
# 	Num. of transactions: 48337
# 	Num. of freq itemsets: 0
# 	Finished data-stream #15 in 0.66 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #16
# 	Num. of transactions: 47794
# 	Num. of freq itemsets: 3
# 	Finished data-stream #16 in 0.7 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #17
# 	Num. of transactions: 49624
# 	Num. of freq itemsets: 4
# 	Finished data-stream #17 in 0.72 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #18
# 	Num. of transactions: 47560
# 	Num. of freq itemsets: 1
# 	Finished data-stream #18 in 0.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #19
# 	Num. of transactions: 49871
# 	Num. of freq itemsets: 0
# 	Finished data-stream #19 in 0.77 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #20
# 	Num. of transactions: 48651
# 	Num. of freq itemsets: 0
# 	Finished data-stream #20 in 0.73 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #21
# 	Num. of transactions: 45930
# 	Num. of freq itemsets: 0
# 	Finished data-stream #21 in 0.69 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #22
# 	Num. of transactions: 45318
# 	Num. of freq itemsets: 0
# 	Finished data-stream #22 in 0.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #23
# 	Num. of transactions: 43965
# 	Num. of freq itemsets: 0
# 	Finished data-stream #23 in 0.7 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #24
# 	Num. of transactions: 44550
# 	Num. of freq itemsets: 0
# 	Finished data-stream #24 in 0.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #25
# 	Num. of transactions: 43597
# 	Num. of freq itemsets: 0
# 	Finished data-stream #25 in 0.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #26
# 	Num. of transactions: 46778
# 	Num. of freq itemsets: 3
# 	Finished data-stream #26 in 0.76 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #27
# 	Num. of transactions: 43364
# 	Num. of freq itemsets: 6
# 	Finished data-stream #27 in 0.89 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #28
# 	Num. of transactions: 51308
# 	Num. of freq itemsets: 3
# 	Finished data-stream #28 in 0.83 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #29
# 	Num. of transactions: 52861
# 	Num. of freq itemsets: 5
# 	Finished data-stream #29 in 0.96 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #30
# 	Num. of transactions: 54031
# 	Num. of freq itemsets: 5
# 	Finished data-stream #30 in 0.99 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #31
# 	Num. of transactions: 54296
# 	Num. of freq itemsets: 0
# 	Finished data-stream #31 in 0.91 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #32
# 	Num. of transactions: 53686
# 	Num. of freq itemsets: 0
# 	Finished data-stream #32 in 0.9 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #33
# 	Num. of transactions: 53069
# 	Num. of freq itemsets: 0
# 	Finished data-stream #33 in 0.84 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #34
# 	Num. of transactions: 52059
# 	Num. of freq itemsets: 1
# 	Finished data-stream #34 in 0.86 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #35
# 	Num. of transactions: 51115
# 	Num. of freq itemsets: 1
# 	Finished data-stream #35 in 0.87 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #36
# 	Num. of transactions: 51136
# 	Num. of freq itemsets: 0
# 	Finished data-stream #36 in 0.86 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #37
# 	Num. of transactions: 50635
# 	Num. of freq itemsets: 0
# 	Finished data-stream #37 in 0.89 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #38
# 	Num. of transactions: 49040
# 	Num. of freq itemsets: 0
# 	Finished data-stream #38 in 0.86 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #39
# 	Num. of transactions: 47117
# 	Num. of freq itemsets: 0
# 	Finished data-stream #39 in 0.87 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #40
# 	Num. of transactions: 46648
# 	Num. of freq itemsets: 1
# 	Finished data-stream #40 in 0.95 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #41
# 	Num. of transactions: 47530
# 	Num. of freq itemsets: 10
# 	Finished data-stream #41 in 1.36 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #42
# 	Num. of transactions: 52330
# 	Num. of freq itemsets: 9
# 	Finished data-stream #42 in 1.33 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #43
# 	Num. of transactions: 56926
# 	Num. of freq itemsets: 4
# 	Finished data-stream #43 in 1.03 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #44
# 	Num. of transactions: 57645
# 	Num. of freq itemsets: 4
# 	Finished data-stream #44 in 1.08 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #45
# 	Num. of transactions: 56455
# 	Num. of freq itemsets: 0
# 	Finished data-stream #45 in 1.07 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #46
# 	Num. of transactions: 56225
# 	Num. of freq itemsets: 2
# 	Finished data-stream #46 in 0.99 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #47
# 	Num. of transactions: 55367
# 	Num. of freq itemsets: 4
# 	Finished data-stream #47 in 1.13 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #48
# 	Num. of transactions: 52144
# 	Num. of freq itemsets: 0
# 	Finished data-stream #48 in 1.06 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #49
# 	Num. of transactions: 52938
# 	Num. of freq itemsets: 2
# 	Finished data-stream #49 in 1.09 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #50
# 	Num. of transactions: 52634
# 	Num. of freq itemsets: 9
# 	Finished data-stream #50 in 1.45 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #51
# 	Num. of transactions: 52536
# 	Num. of freq itemsets: 5
# 	Finished data-stream #51 in 1.2 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #52
# 	Num. of transactions: 52501
# 	Num. of freq itemsets: 5
# 	Finished data-stream #52 in 1.21 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #53
# 	Num. of transactions: 52812
# 	Num. of freq itemsets: 3
# 	Finished data-stream #53 in 1.14 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #54
# 	Num. of transactions: 52193
# 	Num. of freq itemsets: 3
# 	Finished data-stream #54 in 1.14 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #55
# 	Num. of transactions: 52317
# 	Num. of freq itemsets: 3
# 	Finished data-stream #55 in 1.14 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #56
# 	Num. of transactions: 52151
# 	Num. of freq itemsets: 1
# 	Finished data-stream #56 in 1.12 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #57
# 	Num. of transactions: 51171
# 	Num. of freq itemsets: 5
# 	Finished data-stream #57 in 1.23 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #58
# 	Num. of transactions: 52697
# 	Num. of freq itemsets: 5
# 	Finished data-stream #58 in 1.26 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #59
# 	Num. of transactions: 53499
# 	Num. of freq itemsets: 5
# 	Finished data-stream #59 in 1.26 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #60
# 	Num. of transactions: 53199
# 	Num. of freq itemsets: 4
# 	Finished data-stream #60 in 1.28 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #61
# 	Num. of transactions: 52886
# 	Num. of freq itemsets: 4
# 	Finished data-stream #61 in 1.31 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #62
# 	Num. of transactions: 51929
# 	Num. of freq itemsets: 5
# 	Finished data-stream #62 in 1.29 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #63
# 	Num. of transactions: 51378
# 	Num. of freq itemsets: 1
# 	Finished data-stream #63 in 1.66 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #64
# 	Num. of transactions: 52123
# 	Num. of freq itemsets: 1
# 	Finished data-stream #64 in 1.35 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #65
# 	Num. of transactions: 52851
# 	Num. of freq itemsets: 4
# 	Finished data-stream #65 in 1.33 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #66
# 	Num. of transactions: 53756
# 	Num. of freq itemsets: 0
# 	Finished data-stream #66 in 1.29 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #67
# 	Num. of transactions: 52357
# 	Num. of freq itemsets: 1
# 	Finished data-stream #67 in 1.27 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #68
# 	Num. of transactions: 53716
# 	Num. of freq itemsets: 1
# 	Finished data-stream #68 in 1.28 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #69
# 	Num. of transactions: 53213
# 	Num. of freq itemsets: 2
# 	Finished data-stream #69 in 1.32 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #70
# 	Num. of transactions: 54255
# 	Num. of freq itemsets: 4
# 	Finished data-stream #70 in 1.39 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #71
# 	Num. of transactions: 53763
# 	Num. of freq itemsets: 3
# 	Finished data-stream #71 in 1.38 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #72
# 	Num. of transactions: 55402
# 	Num. of freq itemsets: 1
# 	Finished data-stream #72 in 1.38 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #73
# 	Num. of transactions: 53495
# 	Num. of freq itemsets: 2
# 	Finished data-stream #73 in 1.36 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #74
# 	Num. of transactions: 55494
# 	Num. of freq itemsets: 0
# 	Finished data-stream #74 in 1.39 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #75
# 	Num. of transactions: 56344
# 	Num. of freq itemsets: 4
# 	Finished data-stream #75 in 1.49 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #76
# 	Num. of transactions: 52960
# 	Num. of freq itemsets: 3
# 	Finished data-stream #76 in 1.4 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #77
# 	Num. of transactions: 48963
# 	Num. of freq itemsets: 0
# 	Finished data-stream #77 in 1.32 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #78
# 	Num. of transactions: 50350
# 	Num. of freq itemsets: 0
# 	Finished data-stream #78 in 1.36 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #79
# 	Num. of transactions: 49555
# 	Num. of freq itemsets: 0
# 	Finished data-stream #79 in 1.36 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #80
# 	Num. of transactions: 49519
# 	Num. of freq itemsets: 0
# 	Finished data-stream #80 in 1.38 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #81
# 	Num. of transactions: 49554
# 	Num. of freq itemsets: 0
# 	Finished data-stream #81 in 1.36 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #82
# 	Num. of transactions: 49569
# 	Num. of freq itemsets: 0
# 	Finished data-stream #82 in 1.46 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #83
# 	Num. of transactions: 50081
# 	Num. of freq itemsets: 0
# 	Finished data-stream #83 in 1.39 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #84
# 	Num. of transactions: 50118
# 	Num. of freq itemsets: 0
# 	Finished data-stream #84 in 1.46 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #85
# 	Num. of transactions: 50331
# 	Num. of freq itemsets: 0
# 	Finished data-stream #85 in 1.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #86
# 	Num. of transactions: 50689
# 	Num. of freq itemsets: 0
# 	Finished data-stream #86 in 1.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #87
# 	Num. of transactions: 50277
# 	Num. of freq itemsets: 0
# 	Finished data-stream #87 in 1.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #88
# 	Num. of transactions: 50582
# 	Num. of freq itemsets: 0
# 	Finished data-stream #88 in 1.45 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #89
# 	Num. of transactions: 50742
# 	Num. of freq itemsets: 0
# 	Finished data-stream #89 in 1.49 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #90
# 	Num. of transactions: 52028
# 	Num. of freq itemsets: 1
# 	Finished data-stream #90 in 1.51 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #91
# 	Num. of transactions: 53032
# 	Num. of freq itemsets: 1
# 	Finished data-stream #91 in 1.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #92
# 	Num. of transactions: 53785
# 	Num. of freq itemsets: 4
# 	Finished data-stream #92 in 1.64 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #93
# 	Num. of transactions: 54444
# 	Num. of freq itemsets: 4
# 	Finished data-stream #93 in 1.79 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #94
# 	Num. of transactions: 53002
# 	Num. of freq itemsets: 10
# 	Finished data-stream #94 in 2.27 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #95
# 	Num. of transactions: 54331
# 	Num. of freq itemsets: 5
# 	Finished data-stream #95 in 1.87 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #96
# 	Num. of transactions: 52435
# 	Num. of freq itemsets: 6
# 	Finished data-stream #96 in 1.89 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #97
# 	Num. of transactions: 50926
# 	Num. of freq itemsets: 0
# 	Finished data-stream #97 in 1.76 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #98
# 	Num. of transactions: 51477
# 	Num. of freq itemsets: 1
# 	Finished data-stream #98 in 1.86 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #99
# 	Num. of transactions: 53746
# 	Num. of freq itemsets: 2
# 	Finished data-stream #99 in 1.93 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #100
# 	Num. of transactions: 54436
# 	Num. of freq itemsets: 3
# 	Finished data-stream #100 in 1.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #101
# 	Num. of transactions: 52297
# 	Num. of freq itemsets: 1
# 	Finished data-stream #101 in 1.98 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #102
# 	Num. of transactions: 54865
# 	Num. of freq itemsets: 4
# 	Finished data-stream #102 in 1.9 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #103
# 	Num. of transactions: 54911
# 	Num. of freq itemsets: 4
# 	Finished data-stream #103 in 1.94 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #104
# 	Num. of transactions: 54827
# 	Num. of freq itemsets: 4
# 	Finished data-stream #104 in 1.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #105
# 	Num. of transactions: 54195
# 	Num. of freq itemsets: 1
# 	Finished data-stream #105 in 1.83 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #106
# 	Num. of transactions: 56684
# 	Num. of freq itemsets: 2
# 	Finished data-stream #106 in 1.9 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #107
# 	Num. of transactions: 55361
# 	Num. of freq itemsets: 2
# 	Finished data-stream #107 in 1.93 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #108
# 	Num. of transactions: 55566
# 	Num. of freq itemsets: 2
# 	Finished data-stream #108 in 1.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #109
# 	Num. of transactions: 55467
# 	Num. of freq itemsets: 3
# 	Finished data-stream #109 in 1.89 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #110
# 	Num. of transactions: 54996
# 	Num. of freq itemsets: 2
# 	Finished data-stream #110 in 1.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #111
# 	Num. of transactions: 54899
# 	Num. of freq itemsets: 4
# 	Finished data-stream #111 in 1.96 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #112
# 	Num. of transactions: 54180
# 	Num. of freq itemsets: 1
# 	Finished data-stream #112 in 1.89 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #113
# 	Num. of transactions: 54978
# 	Num. of freq itemsets: 2
# 	Finished data-stream #113 in 1.97 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #114
# 	Num. of transactions: 52519
# 	Num. of freq itemsets: 0
# 	Finished data-stream #114 in 1.9 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #115
# 	Num. of transactions: 54126
# 	Num. of freq itemsets: 2
# 	Finished data-stream #115 in 1.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #116
# 	Num. of transactions: 55488
# 	Num. of freq itemsets: 4
# 	Finished data-stream #116 in 2.02 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #117
# 	Num. of transactions: 54641
# 	Num. of freq itemsets: 6
# 	Finished data-stream #117 in 2.1 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #118
# 	Num. of transactions: 54289
# 	Num. of freq itemsets: 3
# 	Finished data-stream #118 in 1.94 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #119
# 	Num. of transactions: 54347
# 	Num. of freq itemsets: 4
# 	Finished data-stream #119 in 1.97 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #120
# 	Num. of transactions: 55496
# 	Num. of freq itemsets: 1
# 	Finished data-stream #120 in 1.95 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #121
# 	Num. of transactions: 54880
# 	Num. of freq itemsets: 2
# 	Finished data-stream #121 in 1.97 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #122
# 	Num. of transactions: 54802
# 	Num. of freq itemsets: 4
# 	Finished data-stream #122 in 2.06 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #123
# 	Num. of transactions: 54300
# 	Num. of freq itemsets: 2
# 	Finished data-stream #123 in 1.97 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #124
# 	Num. of transactions: 54777
# 	Num. of freq itemsets: 3
# 	Finished data-stream #124 in 2.01 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #125
# 	Num. of transactions: 55155
# 	Num. of freq itemsets: 3
# 	Finished data-stream #125 in 2.06 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #126
# 	Num. of transactions: 54156
# 	Num. of freq itemsets: 0
# 	Finished data-stream #126 in 2.01 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #127
# 	Num. of transactions: 56047
# 	Num. of freq itemsets: 1
# 	Finished data-stream #127 in 2.11 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #128
# 	Num. of transactions: 55397
# 	Num. of freq itemsets: 7
# 	Finished data-stream #128 in 2.31 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #129
# 	Num. of transactions: 55228
# 	Num. of freq itemsets: 1
# 	Finished data-stream #129 in 2.07 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #130
# 	Num. of transactions: 56115
# 	Num. of freq itemsets: 2
# 	Finished data-stream #130 in 2.13 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #131
# 	Num. of transactions: 54028
# 	Num. of freq itemsets: 4
# 	Finished data-stream #131 in 2.2 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #132
# 	Num. of transactions: 53185
# 	Num. of freq itemsets: 1
# 	Finished data-stream #132 in 2.05 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #133
# 	Num. of transactions: 55415
# 	Num. of freq itemsets: 0
# 	Finished data-stream #133 in 2.12 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #134
# 	Num. of transactions: 54923
# 	Num. of freq itemsets: 4
# 	Finished data-stream #134 in 2.24 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #135
# 	Num. of transactions: 53794
# 	Num. of freq itemsets: 3
# 	Finished data-stream #135 in 2.22 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #136
# 	Num. of transactions: 54482
# 	Num. of freq itemsets: 3
# 	Finished data-stream #136 in 3.37 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #137
# 	Num. of transactions: 55211
# 	Num. of freq itemsets: 3
# 	Finished data-stream #137 in 2.42 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #138
# 	Num. of transactions: 55390
# 	Num. of freq itemsets: 2
# 	Finished data-stream #138 in 2.46 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #139
# 	Num. of transactions: 56178
# 	Num. of freq itemsets: 3
# 	Finished data-stream #139 in 2.65 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #140
# 	Num. of transactions: 55090
# 	Num. of freq itemsets: 1
# 	Finished data-stream #140 in 2.39 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #141
# 	Num. of transactions: 54494
# 	Num. of freq itemsets: 3
# 	Finished data-stream #141 in 2.44 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #142
# 	Num. of transactions: 52972
# 	Num. of freq itemsets: 7
# 	Finished data-stream #142 in 2.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #143
# 	Num. of transactions: 55578
# 	Num. of freq itemsets: 1
# 	Finished data-stream #143 in 2.27 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #144
# 	Num. of transactions: 54667
# 	Num. of freq itemsets: 1
# 	Finished data-stream #144 in 2.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #145
# 	Num. of transactions: 54760
# 	Num. of freq itemsets: 0
# 	Finished data-stream #145 in 2.38 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #146
# 	Num. of transactions: 54890
# 	Num. of freq itemsets: 4
# 	Finished data-stream #146 in 2.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #147
# 	Num. of transactions: 55834
# 	Num. of freq itemsets: 2
# 	Finished data-stream #147 in 2.36 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #148
# 	Num. of transactions: 54718
# 	Num. of freq itemsets: 1
# 	Finished data-stream #148 in 2.35 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #149
# 	Num. of transactions: 54112
# 	Num. of freq itemsets: 0
# 	Finished data-stream #149 in 2.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #150
# 	Num. of transactions: 54177
# 	Num. of freq itemsets: 7
# 	Finished data-stream #150 in 2.7 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #151
# 	Num. of transactions: 55489
# 	Num. of freq itemsets: 5
# 	Finished data-stream #151 in 2.6 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #152
# 	Num. of transactions: 54412
# 	Num. of freq itemsets: 1
# 	Finished data-stream #152 in 2.41 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #153
# 	Num. of transactions: 55954
# 	Num. of freq itemsets: 2
# 	Finished data-stream #153 in 2.56 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #154
# 	Num. of transactions: 54083
# 	Num. of freq itemsets: 7
# 	Finished data-stream #154 in 2.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #155
# 	Num. of transactions: 54358
# 	Num. of freq itemsets: 4
# 	Finished data-stream #155 in 2.55 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #156
# 	Num. of transactions: 53877
# 	Num. of freq itemsets: 2
# 	Finished data-stream #156 in 2.5 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #157
# 	Num. of transactions: 56935
# 	Num. of freq itemsets: 1
# 	Finished data-stream #157 in 2.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #158
# 	Num. of transactions: 54325
# 	Num. of freq itemsets: 5
# 	Finished data-stream #158 in 2.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #159
# 	Num. of transactions: 54315
# 	Num. of freq itemsets: 4
# 	Finished data-stream #159 in 2.64 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #160
# 	Num. of transactions: 54322
# 	Num. of freq itemsets: 3
# 	Finished data-stream #160 in 2.59 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #161
# 	Num. of transactions: 52775
# 	Num. of freq itemsets: 1
# 	Finished data-stream #161 in 2.66 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #162
# 	Num. of transactions: 49005
# 	Num. of freq itemsets: 0
# 	Finished data-stream #162 in 2.7 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #163
# 	Num. of transactions: 47419
# 	Num. of freq itemsets: 0
# 	Finished data-stream #163 in 2.52 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #164
# 	Num. of transactions: 49846
# 	Num. of freq itemsets: 0
# 	Finished data-stream #164 in 2.66 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #165
# 	Num. of transactions: 52108
# 	Num. of freq itemsets: 0
# 	Finished data-stream #165 in 2.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #166
# 	Num. of transactions: 52246
# 	Num. of freq itemsets: 0
# 	Finished data-stream #166 in 2.6 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #167
# 	Num. of transactions: 51339
# 	Num. of freq itemsets: 0
# 	Finished data-stream #167 in 2.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #168
# 	Num. of transactions: 51294
# 	Num. of freq itemsets: 0
# 	Finished data-stream #168 in 2.68 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #169
# 	Num. of transactions: 51311
# 	Num. of freq itemsets: 0
# 	Finished data-stream #169 in 2.99 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #170
# 	Num. of transactions: 52109
# 	Num. of freq itemsets: 0
# 	Finished data-stream #170 in 2.77 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #171
# 	Num. of transactions: 53316
# 	Num. of freq itemsets: 0
# 	Finished data-stream #171 in 2.61 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #172
# 	Num. of transactions: 52183
# 	Num. of freq itemsets: 0
# 	Finished data-stream #172 in 2.8 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #173
# 	Num. of transactions: 52941
# 	Num. of freq itemsets: 0
# 	Finished data-stream #173 in 3.09 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #174
# 	Num. of transactions: 52432
# 	Num. of freq itemsets: 0
# 	Finished data-stream #174 in 2.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #175
# 	Num. of transactions: 51900
# 	Num. of freq itemsets: 0
# 	Finished data-stream #175 in 3.69 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #176
# 	Num. of transactions: 52385
# 	Num. of freq itemsets: 0
# 	Finished data-stream #176 in 3.01 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #177
# 	Num. of transactions: 52262
# 	Num. of freq itemsets: 0
# 	Finished data-stream #177 in 2.8 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #178
# 	Num. of transactions: 52887
# 	Num. of freq itemsets: 0
# 	Finished data-stream #178 in 2.69 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #179
# 	Num. of transactions: 53872
# 	Num. of freq itemsets: 0
# 	Finished data-stream #179 in 2.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #180
# 	Num. of transactions: 53435
# 	Num. of freq itemsets: 0
# 	Finished data-stream #180 in 2.73 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #181
# 	Num. of transactions: 53506
# 	Num. of freq itemsets: 0
# 	Finished data-stream #181 in 2.85 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #182
# 	Num. of transactions: 52365
# 	Num. of freq itemsets: 0
# 	Finished data-stream #182 in 2.81 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #183
# 	Num. of transactions: 53293
# 	Num. of freq itemsets: 0
# 	Finished data-stream #183 in 2.79 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #184
# 	Num. of transactions: 52886
# 	Num. of freq itemsets: 0
# 	Finished data-stream #184 in 2.75 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #185
# 	Num. of transactions: 51442
# 	Num. of freq itemsets: 0
# 	Finished data-stream #185 in 3.39 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #186
# 	Num. of transactions: 52001
# 	Num. of freq itemsets: 0
# 	Finished data-stream #186 in 3.45 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #187
# 	Num. of transactions: 52976
# 	Num. of freq itemsets: 0
# 	Finished data-stream #187 in 3.65 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #188
# 	Num. of transactions: 52180
# 	Num. of freq itemsets: 0
# 	Finished data-stream #188 in 3.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #189
# 	Num. of transactions: 52982
# 	Num. of freq itemsets: 0
# 	Finished data-stream #189 in 3.57 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #190
# 	Num. of transactions: 52355
# 	Num. of freq itemsets: 0
# 	Finished data-stream #190 in 3.58 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #191
# 	Num. of transactions: 51850
# 	Num. of freq itemsets: 0
# 	Finished data-stream #191 in 3.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #192
# 	Num. of transactions: 52461
# 	Num. of freq itemsets: 0
# 	Finished data-stream #192 in 3.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #193
# 	Num. of transactions: 52038
# 	Num. of freq itemsets: 0
# 	Finished data-stream #193 in 3.84 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #194
# 	Num. of transactions: 51897
# 	Num. of freq itemsets: 0
# 	Finished data-stream #194 in 4.0 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #195
# 	Num. of transactions: 51518
# 	Num. of freq itemsets: 0
# 	Finished data-stream #195 in 4.17 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #196
# 	Num. of transactions: 51881
# 	Num. of freq itemsets: 0
# 	Finished data-stream #196 in 4.1 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #197
# 	Num. of transactions: 50134
# 	Num. of freq itemsets: 0
# 	Finished data-stream #197 in 4.27 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #198
# 	Num. of transactions: 51058
# 	Num. of freq itemsets: 0
# 	Finished data-stream #198 in 4.29 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #199
# 	Num. of transactions: 50992
# 	Num. of freq itemsets: 0
# 	Finished data-stream #199 in 4.53 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #200
# 	Num. of transactions: 50600
# 	Num. of freq itemsets: 0
# 	Finished data-stream #200 in 4.59 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #201
# 	Num. of transactions: 50942
# 	Num. of freq itemsets: 0
# 	Finished data-stream #201 in 4.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #202
# 	Num. of transactions: 51385
# 	Num. of freq itemsets: 0
# 	Finished data-stream #202 in 5.55 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #203
# 	Num. of transactions: 50194
# 	Num. of freq itemsets: 0
# 	Finished data-stream #203 in 5.51 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #204
# 	Num. of transactions: 50756
# 	Num. of freq itemsets: 0
# 	Finished data-stream #204 in 5.95 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #205
# 	Num. of transactions: 49467
# 	Num. of freq itemsets: 8
# 	Finished data-stream #205 in 5.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #206
# 	Num. of transactions: 52705
# 	Num. of freq itemsets: 1
# 	Finished data-stream #206 in 5.26 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #207
# 	Num. of transactions: 49697
# 	Num. of freq itemsets: 1
# 	Finished data-stream #207 in 5.59 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #208
# 	Num. of transactions: 53813
# 	Num. of freq itemsets: 11
# 	Finished data-stream #208 in 6.45 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #209
# 	Num. of transactions: 53494
# 	Num. of freq itemsets: 8
# 	Finished data-stream #209 in 5.64 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #210
# 	Num. of transactions: 53343
# 	Num. of freq itemsets: 7
# 	Finished data-stream #210 in 5.53 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #211
# 	Num. of transactions: 53604
# 	Num. of freq itemsets: 10
# 	Finished data-stream #211 in 5.7 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #212
# 	Num. of transactions: 51669
# 	Num. of freq itemsets: 11
# 	Finished data-stream #212 in 5.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #213
# 	Num. of transactions: 56262
# 	Num. of freq itemsets: 7
# 	Finished data-stream #213 in 5.21 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #214
# 	Num. of transactions: 53619
# 	Num. of freq itemsets: 11
# 	Finished data-stream #214 in 5.66 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #215
# 	Num. of transactions: 50128
# 	Num. of freq itemsets: 12
# 	Finished data-stream #215 in 5.56 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #216
# 	Num. of transactions: 58405
# 	Num. of freq itemsets: 11
# 	Finished data-stream #216 in 5.53 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #217
# 	Num. of transactions: 54204
# 	Num. of freq itemsets: 15
# 	Finished data-stream #217 in 7.51 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #218
# 	Num. of transactions: 56491
# 	Num. of freq itemsets: 17
# 	Finished data-stream #218 in 6.91 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #219
# 	Num. of transactions: 56850
# 	Num. of freq itemsets: 14
# 	Finished data-stream #219 in 5.94 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #220
# 	Num. of transactions: 53979
# 	Num. of freq itemsets: 10
# 	Finished data-stream #220 in 5.18 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #221
# 	Num. of transactions: 53574
# 	Num. of freq itemsets: 6
# 	Finished data-stream #221 in 4.69 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #222
# 	Num. of transactions: 54599
# 	Num. of freq itemsets: 11
# 	Finished data-stream #222 in 5.3 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #223
# 	Num. of transactions: 52317
# 	Num. of freq itemsets: 9
# 	Finished data-stream #223 in 4.81 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #224
# 	Num. of transactions: 51760
# 	Num. of freq itemsets: 11
# 	Finished data-stream #224 in 5.22 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #225
# 	Num. of transactions: 52540
# 	Num. of freq itemsets: 7
# 	Finished data-stream #225 in 4.49 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #226
# 	Num. of transactions: 51957
# 	Num. of freq itemsets: 5
# 	Finished data-stream #226 in 4.21 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #227
# 	Num. of transactions: 51149
# 	Num. of freq itemsets: 8
# 	Finished data-stream #227 in 4.53 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #228
# 	Num. of transactions: 51997
# 	Num. of freq itemsets: 4
# 	Finished data-stream #228 in 4.1 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #229
# 	Num. of transactions: 52116
# 	Num. of freq itemsets: 5
# 	Finished data-stream #229 in 4.29 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #230
# 	Num. of transactions: 51907
# 	Num. of freq itemsets: 7
# 	Finished data-stream #230 in 4.45 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #231
# ...
# --------------------------------------------------------------------------------
# 	Accessing data-stream #490
# 	Num. of transactions: 53316
# 	Num. of freq itemsets: 5
# 	Finished data-stream #490 in 11.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #491
# 	Num. of transactions: 54519
# 	Num. of freq itemsets: 0
# 	Finished data-stream #491 in 12.53 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #492
# 	Num. of transactions: 53252
# 	Num. of freq itemsets: 0
# 	Finished data-stream #492 in 11.97 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #493
# 	Num. of transactions: 52578
# 	Num. of freq itemsets: 9
# 	Finished data-stream #493 in 11.88 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #494
# 	Num. of transactions: 55572
# 	Num. of freq itemsets: 7
# 	Finished data-stream #494 in 11.45 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #495
# 	Num. of transactions: 53571
# 	Num. of freq itemsets: 3
# 	Finished data-stream #495 in 11.13 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #496
# 	Num. of transactions: 50668
# 	Num. of freq itemsets: 3
# 	Finished data-stream #496 in 10.91 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #497
# 	Num. of transactions: 51091
# 	Num. of freq itemsets: 1
# 	Finished data-stream #497 in 12.08 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #498
# 	Num. of transactions: 51798
# 	Num. of freq itemsets: 3
# 	Finished data-stream #498 in 13.25 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #499
# 	Num. of transactions: 50507
# 	Num. of freq itemsets: 5
# 	Finished data-stream #499 in 13.09 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #500
# 	Num. of transactions: 52593
# 	Num. of freq itemsets: 1
# 	Finished data-stream #500 in 12.81 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #501
# 	Num. of transactions: 55337
# 	Num. of freq itemsets: 5
# 	Finished data-stream #501 in 13.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #502
# 	Num. of transactions: 52370
# 	Num. of freq itemsets: 5
# 	Finished data-stream #502 in 14.59 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #503
# 	Num. of transactions: 49976
# 	Num. of freq itemsets: 4
# 	Finished data-stream #503 in 13.76 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #504
# 	Num. of transactions: 53363
# 	Num. of freq itemsets: 3
# 	Finished data-stream #504 in 13.61 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #505
# 	Num. of transactions: 53668
# 	Num. of freq itemsets: 0
# 	Finished data-stream #505 in 13.57 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #506
# 	Num. of transactions: 52667
# 	Num. of freq itemsets: 0
# 	Finished data-stream #506 in 12.58 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #507
# 	Num. of transactions: 53157
# 	Num. of freq itemsets: 1
# 	Finished data-stream #507 in 11.97 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #508
# 	Num. of transactions: 53592
# 	Num. of freq itemsets: 5
# 	Finished data-stream #508 in 11.43 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #509
# 	Num. of transactions: 54683
# 	Num. of freq itemsets: 0
# 	Finished data-stream #509 in 11.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #510
# 	Num. of transactions: 52955
# 	Num. of freq itemsets: 0
# 	Finished data-stream #510 in 11.4 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #511
# 	Num. of transactions: 51509
# 	Num. of freq itemsets: 6
# 	Finished data-stream #511 in 11.21 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #512
# 	Num. of transactions: 51539
# 	Num. of freq itemsets: 6
# 	Finished data-stream #512 in 11.82 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #513
# 	Num. of transactions: 50462
# 	Num. of freq itemsets: 9
# 	Finished data-stream #513 in 12.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #514
# 	Num. of transactions: 47890
# 	Num. of freq itemsets: 4
# 	Finished data-stream #514 in 14.89 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #515
# 	Num. of transactions: 50806
# 	Num. of freq itemsets: 7
# 	Finished data-stream #515 in 12.77 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #516
# 	Num. of transactions: 54859
# 	Num. of freq itemsets: 8
# 	Finished data-stream #516 in 15.05 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #517
# 	Num. of transactions: 51599
# 	Num. of freq itemsets: 4
# 	Finished data-stream #517 in 13.65 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #518
# 	Num. of transactions: 41421
# 	Num. of freq itemsets: 0
# 	Finished data-stream #518 in 13.02 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #519
# 	Num. of transactions: 49626
# 	Num. of freq itemsets: 1
# 	Finished data-stream #519 in 12.22 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #520
# 	Num. of transactions: 51020
# 	Num. of freq itemsets: 7
# 	Finished data-stream #520 in 14.87 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #521
# 	Num. of transactions: 47293
# 	Num. of freq itemsets: 1
# 	Finished data-stream #521 in 14.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #522
# 	Num. of transactions: 55189
# 	Num. of freq itemsets: 5
# 	Finished data-stream #522 in 12.71 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #523
# 	Num. of transactions: 50971
# 	Num. of freq itemsets: 11
# 	Finished data-stream #523 in 13.43 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #524
# 	Num. of transactions: 55537
# 	Num. of freq itemsets: 13
# 	Finished data-stream #524 in 14.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #525
# 	Num. of transactions: 57674
# 	Num. of freq itemsets: 14
# 	Finished data-stream #525 in 15.31 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #526
# 	Num. of transactions: 56528
# 	Num. of freq itemsets: 6
# 	Finished data-stream #526 in 12.55 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #527
# 	Num. of transactions: 49694
# 	Num. of freq itemsets: 4
# 	Finished data-stream #527 in 13.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #528
# 	Num. of transactions: 51335
# 	Num. of freq itemsets: 4
# 	Finished data-stream #528 in 13.31 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #529
# 	Num. of transactions: 49966
# 	Num. of freq itemsets: 4
# 	Finished data-stream #529 in 12.04 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #530
# 	Num. of transactions: 52452
# 	Num. of freq itemsets: 3
# 	Finished data-stream #530 in 11.78 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #531
# 	Num. of transactions: 44782
# 	Num. of freq itemsets: 1
# 	Finished data-stream #531 in 12.37 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #532
# 	Num. of transactions: 52073
# 	Num. of freq itemsets: 0
# 	Finished data-stream #532 in 11.72 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #533
# 	Num. of transactions: 51092
# 	Num. of freq itemsets: 3
# 	Finished data-stream #533 in 13.57 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #534
# 	Num. of transactions: 56052
# 	Num. of freq itemsets: 8
# 	Finished data-stream #534 in 14.1 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #535
# 	Num. of transactions: 53702
# 	Num. of freq itemsets: 4
# 	Finished data-stream #535 in 13.7 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #536
# 	Num. of transactions: 54714
# 	Num. of freq itemsets: 1
# 	Finished data-stream #536 in 12.43 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #537
# 	Num. of transactions: 51000
# 	Num. of freq itemsets: 7
# 	Finished data-stream #537 in 12.36 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #538
# 	Num. of transactions: 54997
# 	Num. of freq itemsets: 3
# 	Finished data-stream #538 in 11.72 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #539
# 	Num. of transactions: 55910
# 	Num. of freq itemsets: 4
# 	Finished data-stream #539 in 11.82 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #540
# 	Num. of transactions: 56783
# 	Num. of freq itemsets: 13
# 	Finished data-stream #540 in 12.33 seconds.
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb Cell 6 line 2
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=25'>26</a> for stream_id in range(num_streams):
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a>     start_time = time.time()
# ---> <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=28'>29</a>     df = datastream.getCurrentStream(stream_id)
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a>     if dataset == 'movielens':
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a>         movie_transactions = preprocess(dataset_name=dataset,
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=32'>33</a>                                         ratings=df,
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a>                                         movies=movies_df,
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets_AmznRev1K.ipynb#W5sZmlsZQ%3D%3D?line=34'>35</a>                                         threshold_rating=threshold_rating)
#
# File ~/Desktop/Projects/FrequentMining/preprocessor.py:9, in Streamer.getCurrentStream(self, stream_id)
#       8 def getCurrentStream(self, stream_id):
# ----> 9     return pd.read_csv(self.filepath,
#      10                        skiprows=stream_id*self.stream_limit,
#      11                        nrows=self.stream_limit,
#      12                        header=None,
#      13                        low_memory=True,
#      14                        )
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:787, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:331, in getstate(self)
#
# KeyboardInterrupt:
