# %%
import pandas as pd
import time
import warnings
from apriori_algorithm import AprioriAlgorithm
from preprocessor import Streamer, preprocess
from colorama import Fore

warnings.filterwarnings('ignore')

# %%
dataset_metadata = {
    'amazon-reviews': {
        'path': './data/amazon-reviews/all_csv_files.csv',

        # using only half the dataset
        'size': 233055326//2,  # original size = 233055326

        'limit': 70000,
        'minsup': [25000]
    },

    'groceries': {
        'path': './data/groceries/Groceries_dataset.csv',
        'size': 38766,
        'limit': 10000,
        'minsup': [200, 150, 100, 50, 25, 10]
    },


    'movielens': {
        'path': ['./data/movielens/ratings.csv', './data/movielens/movies.csv'],
        'size': 100836,
        'limit': 50000,
        'minsup': [500, 400, 300, 200, 100, 50]
    }
}

# %%
MIN_SUPPORT = 100
VERBOSE = False
DISPLAY_ITERATION = 5000

# %%
datasets = [
    # 'groceries',
    # 'movielens',
    'amazon-reviews',
    ]

# %%
threshold_rating = 4.0

# %%
for dataset in datasets:
    
    results = pd.DataFrame(columns=['item_sets', 'supp_count'])
    dataset_meta = dataset_metadata[dataset]
    num_streams = dataset_meta['size'] // dataset_meta['limit']
    
    total_time = 0
    total_timer = time.time()
    
    for minsup in dataset_meta['minsup']:
        
        apriori = AprioriAlgorithm(minsup= minsup, verbose=VERBOSE)
        
        if dataset == 'movielens':
            datastream = Streamer(filepath=dataset_meta['path'][0],
                                stream_limit=dataset_meta['limit'])
            movies_df = pd.read_csv(dataset_meta['path'][1])

        else:
            datastream = Streamer(filepath=dataset_meta['path'],
                                stream_limit=dataset_meta['limit'])
        
        print(Fore.WHITE + f'Running Apriori on {dataset} : streams = {num_streams} , minsup = {minsup}')
        print(Fore.WHITE + "##"*40)
        
        for stream_id in range(num_streams):

            start_time = time.time()
            df = datastream.getCurrentStream(stream_id)

            if dataset == 'movielens':
                movie_transactions = preprocess(dataset_name=dataset,
                                                ratings=df,
                                                movies=movies_df,
                                                threshold_rating=threshold_rating)

            else:
                movie_transactions = preprocess(dataset_name=dataset, 
                                                df=df, 
                                                threshold_rating=threshold_rating)
                
        
            freq_item_sets = apriori.run(movie_transactions)
            
            results = pd.concat([results, freq_item_sets], ignore_index=True)
            results = results.drop_duplicates()
            
                
            
            if len(freq_item_sets) > 0 or VERBOSE or stream_id == 0 or stream_id % DISPLAY_ITERATION == 0:
                print(Fore.WHITE + f'\tAccessing data-stream #{stream_id}')
                print(Fore.GREEN + f'\tNum. of transactions: {len(movie_transactions)}')
                print(Fore.GREEN + f'\tNum. of freq itemsets: {len(freq_item_sets)}')
                
                time_taken = round(time.time() - start_time, 2)
                print(Fore.WHITE + f'\tFinished data-stream #{stream_id} in {time_taken} seconds.')

                print(Fore.WHITE + '--'*40)
    
        # display(results)
        results.to_csv(f'./logs/{dataset}/itemsets_df_minsup_{minsup}.csv', index=False)
        
    
    total_time += time.time() - total_timer
    print(Fore.GREEN + f'Completed {dataset} dataset in {total_time:.2f} seconds.')

    print(Fore.WHITE + "##"*40, '\n\n')
# Out:
# Running Apriori on groceries : streams = 3 , minsup = 150
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 3512
# 	Num. of freq itemsets: 20
# 	Finished data-stream #0 in 0.23 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 3664
# 	Num. of freq itemsets: 14
# 	Finished data-stream #1 in 0.12 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #2
# 	Num. of transactions: 3567
# 	Num. of freq itemsets: 19
# 	Finished data-stream #2 in 0.19 seconds.
# --------------------------------------------------------------------------------
# Running Apriori on groceries : streams = 3 , minsup = 100
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 3512
# 	Num. of freq itemsets: 4
# 	Finished data-stream #0 in 0.23 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 3664
# 	Num. of freq itemsets: 1
# 	Finished data-stream #1 in 0.32 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #2
# 	Num. of transactions: 3567
# 	Num. of freq itemsets: 27
# 	Finished data-stream #2 in 0.37 seconds.
# --------------------------------------------------------------------------------
# Running Apriori on groceries : streams = 3 , minsup = 50
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 3512
# 	Num. of freq itemsets: 34
# 	Finished data-stream #0 in 0.67 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 3664
# 	Num. of freq itemsets: 14
# 	Finished data-stream #1 in 1.1 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #2
# 	Num. of transactions: 3567
# 	Num. of freq itemsets: 8
# 	Finished data-stream #2 in 1.3 seconds.
# --------------------------------------------------------------------------------
# Running Apriori on groceries : streams = 3 , minsup = 25
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 3512
# 	Num. of freq itemsets: 1
# 	Finished data-stream #0 in 1.78 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 3664
# 	Num. of freq itemsets: 47
# 	Finished data-stream #1 in 2.47 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #2
# 	Num. of transactions: 3567
# 	Num. of freq itemsets: 46
# 	Finished data-stream #2 in 2.73 seconds.
# --------------------------------------------------------------------------------
# Completed groceries dataset in 11.533413887023926 seconds.
# ################################################################################
#
# Running Apriori on movielens : streams = 2 , minsup = 300
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 322
# 	Num. of freq itemsets: 2
# 	Finished data-stream #0 in 0.03 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 288
# 	Num. of freq itemsets: 2
# 	Finished data-stream #1 in 0.03 seconds.
# --------------------------------------------------------------------------------
# Running Apriori on movielens : streams = 2 , minsup = 200
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 322
# 	Num. of freq itemsets: 2
# 	Finished data-stream #0 in 0.02 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 288
# 	Num. of freq itemsets: 2
# 	Finished data-stream #1 in 0.03 seconds.
# --------------------------------------------------------------------------------
# Running Apriori on movielens : streams = 2 , minsup = 100
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 322
# 	Num. of freq itemsets: 8
# 	Finished data-stream #0 in 0.23 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 288
# 	Num. of freq itemsets: 5
# 	Finished data-stream #1 in 0.2 seconds.
# --------------------------------------------------------------------------------
# Running Apriori on movielens : streams = 2 , minsup = 50
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 322
# 	Num. of freq itemsets: 10
# 	Finished data-stream #0 in 4.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #1
# 	Num. of transactions: 288
# 	Num. of freq itemsets: 1
# 	Finished data-stream #1 in 3.65 seconds.
# --------------------------------------------------------------------------------
# Completed movielens dataset in 8.842831134796143 seconds.
# ################################################################################
#
# Running Apriori on amazon-reviews : streams = 1664 , minsup = 5000
# ################################################################################
# 	Accessing data-stream #0
# 	Num. of transactions: 48514
# 	Num. of freq itemsets: 1
# 	Finished data-stream #0 in 0.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #2
# 	Num. of transactions: 52371
# 	Num. of freq itemsets: 1
# 	Finished data-stream #2 in 0.54 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #8
# 	Num. of transactions: 46400
# 	Num. of freq itemsets: 2
# 	Finished data-stream #8 in 0.55 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #9
# 	Num. of transactions: 52353
# 	Num. of freq itemsets: 3
# 	Finished data-stream #9 in 0.63 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #10
# 	Num. of transactions: 43044
# 	Num. of freq itemsets: 1
# 	Finished data-stream #10 in 0.61 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #11
# 	Num. of transactions: 52607
# 	Num. of freq itemsets: 4
# 	Finished data-stream #11 in 0.68 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #12
# 	Num. of transactions: 50342
# 	Num. of freq itemsets: 3
# 	Finished data-stream #12 in 0.66 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #13
# 	Num. of transactions: 54023
# 	Num. of freq itemsets: 3
# 	Finished data-stream #13 in 0.7 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #29
# 	Num. of transactions: 52861
# 	Num. of freq itemsets: 1
# 	Finished data-stream #29 in 0.8 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #41
# 	Num. of transactions: 47530
# 	Num. of freq itemsets: 1
# 	Finished data-stream #41 in 0.85 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #98
# 	Num. of transactions: 51477
# 	Num. of freq itemsets: 1
# 	Finished data-stream #98 in 1.62 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #208
# 	Num. of transactions: 53813
# 	Num. of freq itemsets: 1
# 	Finished data-stream #208 in 3.47 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #209
# 	Num. of transactions: 53494
# 	Num. of freq itemsets: 1
# 	Finished data-stream #209 in 3.52 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #210
# 	Num. of transactions: 53343
# 	Num. of freq itemsets: 2
# 	Finished data-stream #210 in 3.41 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #211
# 	Num. of transactions: 53604
# 	Num. of freq itemsets: 1
# 	Finished data-stream #211 in 3.42 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #212
# 	Num. of transactions: 51669
# 	Num. of freq itemsets: 1
# 	Finished data-stream #212 in 3.38 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #213
# 	Num. of transactions: 56262
# 	Num. of freq itemsets: 5
# 	Finished data-stream #213 in 3.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #214
# 	Num. of transactions: 53619
# 	Num. of freq itemsets: 2
# 	Finished data-stream #214 in 3.53 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #215
# 	Num. of transactions: 50128
# 	Num. of freq itemsets: 1
# 	Finished data-stream #215 in 3.34 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #216
# 	Num. of transactions: 58405
# 	Num. of freq itemsets: 1
# 	Finished data-stream #216 in 3.83 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #218
# 	Num. of transactions: 56491
# 	Num. of freq itemsets: 1
# 	Finished data-stream #218 in 3.48 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #219
# 	Num. of transactions: 56850
# 	Num. of freq itemsets: 1
# 	Finished data-stream #219 in 3.73 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #221
# 	Num. of transactions: 53574
# 	Num. of freq itemsets: 1
# 	Finished data-stream #221 in 3.88 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #233
# 	Num. of transactions: 53236
# 	Num. of freq itemsets: 1
# 	Finished data-stream #233 in 3.61 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #234
# 	Num. of transactions: 52918
# 	Num. of freq itemsets: 1
# 	Finished data-stream #234 in 3.58 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #236
# 	Num. of transactions: 52416
# 	Num. of freq itemsets: 1
# 	Finished data-stream #236 in 3.83 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #249
# 	Num. of transactions: 53042
# 	Num. of freq itemsets: 2
# 	Finished data-stream #249 in 3.74 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #252
# 	Num. of transactions: 51909
# 	Num. of freq itemsets: 1
# 	Finished data-stream #252 in 4.23 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #253
# 	Num. of transactions: 53943
# 	Num. of freq itemsets: 4
# 	Finished data-stream #253 in 4.17 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #254
# 	Num. of transactions: 51006
# 	Num. of freq itemsets: 1
# 	Finished data-stream #254 in 3.73 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #255
# 	Num. of transactions: 53252
# 	Num. of freq itemsets: 1
# 	Finished data-stream #255 in 4.14 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #257
# 	Num. of transactions: 51433
# 	Num. of freq itemsets: 1
# 	Finished data-stream #257 in 3.92 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #259
# 	Num. of transactions: 49344
# 	Num. of freq itemsets: 1
# 	Finished data-stream #259 in 3.81 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #261
# 	Num. of transactions: 54689
# 	Num. of freq itemsets: 2
# 	Finished data-stream #261 in 4.06 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #262
# 	Num. of transactions: 54964
# 	Num. of freq itemsets: 1
# 	Finished data-stream #262 in 3.93 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #263
# 	Num. of transactions: 56572
# 	Num. of freq itemsets: 5
# 	Finished data-stream #263 in 4.07 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #264
# 	Num. of transactions: 58448
# 	Num. of freq itemsets: 2
# 	Finished data-stream #264 in 4.08 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #265
# 	Num. of transactions: 56887
# 	Num. of freq itemsets: 2
# 	Finished data-stream #265 in 3.99 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #266
# 	Num. of transactions: 53772
# 	Num. of freq itemsets: 1
# 	Finished data-stream #266 in 4.05 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #267
# 	Num. of transactions: 51461
# 	Num. of freq itemsets: 1
# 	Finished data-stream #267 in 4.09 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #269
# 	Num. of transactions: 54428
# 	Num. of freq itemsets: 2
# 	Finished data-stream #269 in 4.14 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #271
# 	Num. of transactions: 54516
# 	Num. of freq itemsets: 1
# 	Finished data-stream #271 in 4.19 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #272
# 	Num. of transactions: 52828
# 	Num. of freq itemsets: 2
# 	Finished data-stream #272 in 4.1 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #273
# 	Num. of transactions: 53730
# 	Num. of freq itemsets: 1
# 	Finished data-stream #273 in 4.29 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #275
# 	Num. of transactions: 54863
# 	Num. of freq itemsets: 1
# 	Finished data-stream #275 in 3.98 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #281
# 	Num. of transactions: 52229
# 	Num. of freq itemsets: 2
# 	Finished data-stream #281 in 4.11 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #282
# 	Num. of transactions: 52828
# 	Num. of freq itemsets: 1
# 	Finished data-stream #282 in 4.21 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #283
# 	Num. of transactions: 50925
# 	Num. of freq itemsets: 1
# 	Finished data-stream #283 in 3.95 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #284
# 	Num. of transactions: 51962
# 	Num. of freq itemsets: 1
# 	Finished data-stream #284 in 3.98 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #285
# 	Num. of transactions: 52390
# 	Num. of freq itemsets: 2
# 	Finished data-stream #285 in 4.21 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #288
# 	Num. of transactions: 51857
# 	Num. of freq itemsets: 2
# 	Finished data-stream #288 in 4.82 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #290
# 	Num. of transactions: 52729
# 	Num. of freq itemsets: 1
# 	Finished data-stream #290 in 4.5 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #291
# 	Num. of transactions: 55432
# 	Num. of freq itemsets: 1
# 	Finished data-stream #291 in 4.47 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #292
# 	Num. of transactions: 54780
# 	Num. of freq itemsets: 2
# 	Finished data-stream #292 in 4.37 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #303
# 	Num. of transactions: 53021
# 	Num. of freq itemsets: 1
# 	Finished data-stream #303 in 5.07 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #304
# 	Num. of transactions: 54497
# 	Num. of freq itemsets: 1
# 	Finished data-stream #304 in 5.12 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #305
# 	Num. of transactions: 49078
# 	Num. of freq itemsets: 2
# 	Finished data-stream #305 in 4.61 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #307
# 	Num. of transactions: 52105
# 	Num. of freq itemsets: 2
# 	Finished data-stream #307 in 4.52 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #308
# 	Num. of transactions: 50280
# 	Num. of freq itemsets: 2
# 	Finished data-stream #308 in 4.61 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #311
# 	Num. of transactions: 52883
# 	Num. of freq itemsets: 2
# 	Finished data-stream #311 in 4.5 seconds.
# --------------------------------------------------------------------------------
# 	Accessing data-stream #312
# 	Num. of transactions: 54778
# 	Num. of freq itemsets: 2
# 	Finished data-stream #312 in 4.7 seconds.
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb Cell 6 line 2
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=25'>26</a> for stream_id in range(num_streams):
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=27'>28</a>     start_time = time.time()
# ---> <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=28'>29</a>     df = datastream.getCurrentStream(stream_id)
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=30'>31</a>     if dataset == 'movielens':
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=31'>32</a>         movie_transactions = preprocess(dataset_name=dataset,
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=32'>33</a>                                         ratings=df,
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=33'>34</a>                                         movies=movies_df,
#      <a href='vscode-notebook-cell:/Users/siddhantpathak/Desktop/Projects/FrequentMining/02_Apriori_Minsupp_datasets.ipynb#W5sZmlsZQ%3D%3D?line=34'>35</a>                                         threshold_rating=threshold_rating)
#
# File ~/Desktop/Projects/FrequentMining/preprocessor.py:9, in Streamer.getCurrentStream(self, stream_id)
#       8 def getCurrentStream(self, stream_id):
# ----> 9     return pd.read_csv(self.filepath,
#      10                        skiprows=stream_id*self.stream_limit,
#      11                        nrows=self.stream_limit,
#      12                        header=None)
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~/anaconda3/envs/fp_spark/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:787, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:331, in getstate(self)
#
# KeyboardInterrupt:
